# %%
library(betareg)
library(MASS)

# %% [markdown]
# ## Variable Selection with 10 Topics

# %%
data = read.csv('/home/matt/research_data_10.csv')
data[data==0] <- .00001

# %% [markdown]
# ### Percent under 30 Days

# %%
full_model_pct_under_30 <- lm(pct_under_30 ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + 
                              gini_coefficient + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + 
                              gini_coefficientXcrowd_pct + total_contributors + project_age + topic_0*topic_0 + 
                              topic_0*topic_1 + topic_0*topic_2 + topic_0*topic_3 + topic_0*topic_4 + 
                              topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 + topic_0*topic_8 + topic_1*topic_0 + 
                              topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 + topic_1*topic_4 + topic_1*topic_5 + 
                              topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 + topic_2*topic_0 + topic_2*topic_1 + 
                              topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 + topic_2*topic_5 + topic_2*topic_6 + 
                              topic_2*topic_7 + topic_2*topic_8 + topic_3*topic_0 + topic_3*topic_1 + topic_3*topic_2 +
                              topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 + topic_3*topic_6 + topic_3*topic_7 + 
                              topic_3*topic_8 + topic_4*topic_0 + topic_4*topic_1 + topic_4*topic_2 + topic_4*topic_3 + 
                              topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 + topic_4*topic_7 + topic_4*topic_8 + 
                              topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 + topic_5*topic_3 + topic_5*topic_4 + 
                              topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 + topic_5*topic_8 + topic_6*topic_0 + 
                              topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 + topic_6*topic_4 + topic_6*topic_5 + 
                              topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 + topic_7*topic_0 + topic_7*topic_1 + 
                              topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 + topic_7*topic_5 + topic_7*topic_6 + 
                              topic_7*topic_7 + topic_7*topic_8 + topic_8*topic_0 + topic_8*topic_1 + topic_8*topic_2 + 
                              topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 + topic_8*topic_7 + 
                              topic_8*topic_8
                        , data = data)
# Stepwise regression model
step_model_pct_under_30 <- stepAIC(full_model_pct_under_30, direction = "both", trace = FALSE)
summary(step_model_pct_under_30)
# Out:
# Call:
# lm(formula = pct_under_30 ~ crowd_pct + avg_clustering + avg_min_path +
#     gini_coefficientXcrowd_pct + total_contributors + project_age +
#     topic_0 + topic_1 + topic_2 + topic_3 + topic_4 + topic_5 +
#     topic_6 + topic_7 + topic_8 + topic_0:topic_1 + topic_0:topic_5 +
#     topic_0:topic_8 + topic_1:topic_2 + topic_1:topic_3 + topic_1:topic_8 +
#     topic_2:topic_3 + topic_2:topic_6 + topic_2:topic_7 + topic_3:topic_4 +
#     topic_4:topic_7, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.37371 -0.11802 -0.02119  0.10575  0.54125
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 1.041e+00  1.094e-01   9.514  < 2e-16 ***
# crowd_pct                  -7.265e-01  2.068e-01  -3.514  0.00048 ***
# avg_clustering             -3.067e-01  6.016e-02  -5.098 4.77e-07 ***
# avg_min_path               -1.257e-01  3.881e-02  -3.238  0.00128 **
# ...

# %%
summary(full_model_pct_under_30)
# Out:
# Call:
# lm(formula = pct_under_30 ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct + total_contributors +
#     project_age + topic_0 * topic_0 + topic_0 * topic_1 + topic_0 *
#     topic_2 + topic_0 * topic_3 + topic_0 * topic_4 + topic_0 *
#     topic_5 + topic_0 * topic_6 + topic_0 * topic_7 + topic_0 *
#     topic_8 + topic_1 * topic_0 + topic_1 * topic_1 + topic_1 *
#     topic_2 + topic_1 * topic_3 + topic_1 * topic_4 + topic_1 *
#     topic_5 + topic_1 * topic_6 + topic_1 * topic_7 + topic_1 *
#     topic_8 + topic_2 * topic_0 + topic_2 * topic_1 + topic_2 *
#     topic_2 + topic_2 * topic_3 + topic_2 * topic_4 + topic_2 *
#     topic_5 + topic_2 * topic_6 + topic_2 * topic_7 + topic_2 *
#     topic_8 + topic_3 * topic_0 + topic_3 * topic_1 + topic_3 *
#     topic_2 + topic_3 * topic_3 + topic_3 * topic_4 + topic_3 *
# ...

# %% [markdown]
# ### Average Number of Comments

# %%
full_model_avg_comments <- lm(avg_comments ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + 
                              gini_coefficient + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + 
                              gini_coefficientXcrowd_pct + total_contributors + project_age + topic_0*topic_0 + 
                              topic_0*topic_1 + topic_0*topic_2 + topic_0*topic_3 + topic_0*topic_4 + 
                              topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 + topic_0*topic_8 + topic_1*topic_0 + 
                              topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 + topic_1*topic_4 + topic_1*topic_5 + 
                              topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 + topic_2*topic_0 + topic_2*topic_1 + 
                              topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 + topic_2*topic_5 + topic_2*topic_6 + 
                              topic_2*topic_7 + topic_2*topic_8 + topic_3*topic_0 + topic_3*topic_1 + topic_3*topic_2 +
                              topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 + topic_3*topic_6 + topic_3*topic_7 + 
                              topic_3*topic_8 + topic_4*topic_0 + topic_4*topic_1 + topic_4*topic_2 + topic_4*topic_3 + 
                              topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 + topic_4*topic_7 + topic_4*topic_8 + 
                              topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 + topic_5*topic_3 + topic_5*topic_4 + 
                              topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 + topic_5*topic_8 + topic_6*topic_0 + 
                              topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 + topic_6*topic_4 + topic_6*topic_5 + 
                              topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 + topic_7*topic_0 + topic_7*topic_1 + 
                              topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 + topic_7*topic_5 + topic_7*topic_6 + 
                              topic_7*topic_7 + topic_7*topic_8 + topic_8*topic_0 + topic_8*topic_1 + topic_8*topic_2 + 
                              topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 + topic_8*topic_7 + 
                              topic_8*topic_8
                        , data = data)
# Stepwise regression model
step_model_avg_comments <- stepAIC(full_model_avg_comments, direction = "both", 
                      trace = FALSE)
summary(step_model_avg_comments)
# Out:
# Call:
# lm(formula = avg_comments ~ crowd_pct_2 + avg_clustering + avg_min_path +
#     gini_coefficient + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct +
#     topic_0 + topic_1 + topic_3 + topic_4 + topic_6 + topic_7 +
#     topic_8 + topic_0:topic_8 + topic_1:topic_8 + topic_3:topic_4 +
#     topic_3:topic_7 + topic_3:topic_8, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1847 -0.5091 -0.0487  0.3886 10.8758
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                3.7562     0.7559   4.969 9.02e-07 ***
# crowd_pct_2               -2.3845     0.6996  -3.408 0.000702 ***
# avg_clustering             5.1111     0.5236   9.761  < 2e-16 ***
# avg_min_path              -2.9129     0.3129  -9.310  < 2e-16 ***
# gini_coefficient           5.2958     0.8566   6.182 1.24e-09 ***
# avg_clusteringXcrowd_pct  -5.2018     1.1101  -4.686 3.53e-06 ***
# ...

# %%
summary(full_model_avg_comments)
# Out:
# Call:
# lm(formula = avg_comments ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct + total_contributors +
#     project_age + topic_0 * topic_0 + topic_0 * topic_1 + topic_0 *
#     topic_2 + topic_0 * topic_3 + topic_0 * topic_4 + topic_0 *
#     topic_5 + topic_0 * topic_6 + topic_0 * topic_7 + topic_0 *
#     topic_8 + topic_1 * topic_0 + topic_1 * topic_1 + topic_1 *
#     topic_2 + topic_1 * topic_3 + topic_1 * topic_4 + topic_1 *
#     topic_5 + topic_1 * topic_6 + topic_1 * topic_7 + topic_1 *
#     topic_8 + topic_2 * topic_0 + topic_2 * topic_1 + topic_2 *
#     topic_2 + topic_2 * topic_3 + topic_2 * topic_4 + topic_2 *
#     topic_5 + topic_2 * topic_6 + topic_2 * topic_7 + topic_2 *
#     topic_8 + topic_3 * topic_0 + topic_3 * topic_1 + topic_3 *
#     topic_2 + topic_3 * topic_3 + topic_3 * topic_4 + topic_3 *
# ...

# %% [markdown]
# ### Issue Volume

# %%
full_model_volume <- lm(issues_over_time ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + 
                              gini_coefficient + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + 
                              gini_coefficientXcrowd_pct + total_contributors + project_age + topic_0*topic_0 + 
                              topic_0*topic_1 + topic_0*topic_2 + topic_0*topic_3 + topic_0*topic_4 + 
                              topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 + topic_0*topic_8 + topic_1*topic_0 + 
                              topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 + topic_1*topic_4 + topic_1*topic_5 + 
                              topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 + topic_2*topic_0 + topic_2*topic_1 + 
                              topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 + topic_2*topic_5 + topic_2*topic_6 + 
                              topic_2*topic_7 + topic_2*topic_8 + topic_3*topic_0 + topic_3*topic_1 + topic_3*topic_2 +
                              topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 + topic_3*topic_6 + topic_3*topic_7 + 
                              topic_3*topic_8 + topic_4*topic_0 + topic_4*topic_1 + topic_4*topic_2 + topic_4*topic_3 + 
                              topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 + topic_4*topic_7 + topic_4*topic_8 + 
                              topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 + topic_5*topic_3 + topic_5*topic_4 + 
                              topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 + topic_5*topic_8 + topic_6*topic_0 + 
                              topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 + topic_6*topic_4 + topic_6*topic_5 + 
                              topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 + topic_7*topic_0 + topic_7*topic_1 + 
                              topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 + topic_7*topic_5 + topic_7*topic_6 + 
                              topic_7*topic_7 + topic_7*topic_8 + topic_8*topic_0 + topic_8*topic_1 + topic_8*topic_2 + 
                              topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 + topic_8*topic_7 + 
                              topic_8*topic_8
                        , data = data)
# Stepwise regression model
step_model_volume <- stepAIC(full_model_volume, direction = "both", 
                      trace = FALSE)
summary(step_model_volume)
# Out:
# Call:
# lm(formula = issues_over_time ~ crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct + total_contributors +
#     project_age + topic_0 + topic_1 + topic_2 + topic_3 + topic_4 +
#     topic_5 + topic_6 + topic_7 + topic_8 + topic_0:topic_5 +
#     topic_1:topic_5 + topic_2:topic_5 + topic_3:topic_6 + topic_4:topic_5 +
#     topic_4:topic_7 + topic_5:topic_6 + topic_5:topic_7 + topic_6:topic_8,
#     data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -16.384  -2.682  -0.479   1.833  44.842
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                -2.043e+01  5.368e+00  -3.805 0.000158 ***
# crowd_pct_2                 2.931e+01  4.764e+00   6.152 1.50e-09 ***
# avg_clustering             -8.400e+00  3.461e+00  -2.427 0.015557 *
# avg_min_path                5.262e+00  3.033e+00   1.735 0.083373 .
# ...

# %%
summary(full_model_volume)
# Out:
# Call:
# lm(formula = issues_over_time ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct + total_contributors +
#     project_age + topic_0 * topic_0 + topic_0 * topic_1 + topic_0 *
#     topic_2 + topic_0 * topic_3 + topic_0 * topic_4 + topic_0 *
#     topic_5 + topic_0 * topic_6 + topic_0 * topic_7 + topic_0 *
#     topic_8 + topic_1 * topic_0 + topic_1 * topic_1 + topic_1 *
#     topic_2 + topic_1 * topic_3 + topic_1 * topic_4 + topic_1 *
#     topic_5 + topic_1 * topic_6 + topic_1 * topic_7 + topic_1 *
#     topic_8 + topic_2 * topic_0 + topic_2 * topic_1 + topic_2 *
#     topic_2 + topic_2 * topic_3 + topic_2 * topic_4 + topic_2 *
#     topic_5 + topic_2 * topic_6 + topic_2 * topic_7 + topic_2 *
#     topic_8 + topic_3 * topic_0 + topic_3 * topic_1 + topic_3 *
#     topic_2 + topic_3 * topic_3 + topic_3 * topic_4 + topic_3 *
# ...

# %% [markdown]
# ### Average Response Time

# %%
full_model_first_comment <- lm(avg_first_comment ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + 
                              gini_coefficient + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + 
                              gini_coefficientXcrowd_pct + total_contributors + project_age + topic_0*topic_0 + 
                              topic_0*topic_1 + topic_0*topic_2 + topic_0*topic_3 + topic_0*topic_4 + 
                              topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 + topic_0*topic_8 + topic_1*topic_0 + 
                              topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 + topic_1*topic_4 + topic_1*topic_5 + 
                              topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 + topic_2*topic_0 + topic_2*topic_1 + 
                              topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 + topic_2*topic_5 + topic_2*topic_6 + 
                              topic_2*topic_7 + topic_2*topic_8 + topic_3*topic_0 + topic_3*topic_1 + topic_3*topic_2 +
                              topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 + topic_3*topic_6 + topic_3*topic_7 + 
                              topic_3*topic_8 + topic_4*topic_0 + topic_4*topic_1 + topic_4*topic_2 + topic_4*topic_3 + 
                              topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 + topic_4*topic_7 + topic_4*topic_8 + 
                              topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 + topic_5*topic_3 + topic_5*topic_4 + 
                              topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 + topic_5*topic_8 + topic_6*topic_0 + 
                              topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 + topic_6*topic_4 + topic_6*topic_5 + 
                              topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 + topic_7*topic_0 + topic_7*topic_1 + 
                              topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 + topic_7*topic_5 + topic_7*topic_6 + 
                              topic_7*topic_7 + topic_7*topic_8 + topic_8*topic_0 + topic_8*topic_1 + topic_8*topic_2 + 
                              topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 + topic_8*topic_7 + 
                              topic_8*topic_8
                        , data = data)
# Stepwise regression model
step_model_first_comment <- stepAIC(full_model_first_comment, direction = "both", 
                      trace = FALSE)
summary(step_model_first_comment)
# Out:
# Call:
# lm(formula = avg_first_comment ~ crowd_pct_2 + avg_clustering +
#     avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct +
#     project_age + topic_0 + topic_1 + topic_2 + topic_3 + topic_4 +
#     topic_5 + topic_6 + topic_7 + topic_8 + topic_0:topic_8 +
#     topic_1:topic_6 + topic_2:topic_3 + topic_2:topic_6 + topic_4:topic_5 +
#     topic_4:topic_6 + topic_5:topic_7, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -64.861 -14.563  -4.156   8.553 280.825
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 2.426e+01  1.645e+01   1.475  0.14092
# crowd_pct_2                 5.585e+01  2.081e+01   2.683  0.00752 **
# avg_clustering             -3.875e+01  1.626e+01  -2.383  0.01753 *
# avg_clusteringXcrowd_pct    1.159e+02  3.587e+01   3.232  0.00130 **
# avg_min_pathXcrowd_pct      5.471e+01  1.065e+01   5.136 3.93e-07 ***
# ...

# %%
summary(full_model_first_comment)
# Out:
# Call:
# lm(formula = avg_first_comment ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct + total_contributors +
#     project_age + topic_0 * topic_0 + topic_0 * topic_1 + topic_0 *
#     topic_2 + topic_0 * topic_3 + topic_0 * topic_4 + topic_0 *
#     topic_5 + topic_0 * topic_6 + topic_0 * topic_7 + topic_0 *
#     topic_8 + topic_1 * topic_0 + topic_1 * topic_1 + topic_1 *
#     topic_2 + topic_1 * topic_3 + topic_1 * topic_4 + topic_1 *
#     topic_5 + topic_1 * topic_6 + topic_1 * topic_7 + topic_1 *
#     topic_8 + topic_2 * topic_0 + topic_2 * topic_1 + topic_2 *
#     topic_2 + topic_2 * topic_3 + topic_2 * topic_4 + topic_2 *
#     topic_5 + topic_2 * topic_6 + topic_2 * topic_7 + topic_2 *
#     topic_8 + topic_3 * topic_0 + topic_3 * topic_1 + topic_3 *
#     topic_2 + topic_3 * topic_3 + topic_3 * topic_4 + topic_3 *
# ...

# %% [markdown]
# ### Issues Per User

# %%
full_model_issues_per_user <- lm(issues_per_user ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + 
                              gini_coefficient + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + 
                              gini_coefficientXcrowd_pct + total_contributors + project_age + topic_0*topic_0 + 
                              topic_0*topic_1 + topic_0*topic_2 + topic_0*topic_3 + topic_0*topic_4 + 
                              topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 + topic_0*topic_8 + topic_1*topic_0 + 
                              topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 + topic_1*topic_4 + topic_1*topic_5 + 
                              topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 + topic_2*topic_0 + topic_2*topic_1 + 
                              topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 + topic_2*topic_5 + topic_2*topic_6 + 
                              topic_2*topic_7 + topic_2*topic_8 + topic_3*topic_0 + topic_3*topic_1 + topic_3*topic_2 +
                              topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 + topic_3*topic_6 + topic_3*topic_7 + 
                              topic_3*topic_8 + topic_4*topic_0 + topic_4*topic_1 + topic_4*topic_2 + topic_4*topic_3 + 
                              topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 + topic_4*topic_7 + topic_4*topic_8 + 
                              topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 + topic_5*topic_3 + topic_5*topic_4 + 
                              topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 + topic_5*topic_8 + topic_6*topic_0 + 
                              topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 + topic_6*topic_4 + topic_6*topic_5 + 
                              topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 + topic_7*topic_0 + topic_7*topic_1 + 
                              topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 + topic_7*topic_5 + topic_7*topic_6 + 
                              topic_7*topic_7 + topic_7*topic_8 + topic_8*topic_0 + topic_8*topic_1 + topic_8*topic_2 + 
                              topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 + topic_8*topic_7 + 
                              topic_8*topic_8
                        , data = data)
# Stepwise regression model
step_model_issues_per_user <- stepAIC(full_model_issues_per_user, direction = "both", 
                      trace = FALSE)
summary(step_model_issues_per_user)
# Out:
# Call:
# lm(formula = issues_per_user ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct + total_contributors +
#     project_age + topic_0 * topic_0 + topic_0 * topic_1 + topic_0 *
#     topic_2 + topic_0 * topic_3 + topic_0 * topic_4 + topic_0 *
#     topic_5 + topic_0 * topic_6 + topic_0 * topic_7 + topic_0 *
#     topic_8 + topic_1 * topic_0 + topic_1 * topic_1 + topic_1 *
#     topic_2 + topic_1 * topic_3 + topic_1 * topic_4 + topic_1 *
#     topic_5 + topic_1 * topic_6 + topic_1 * topic_7 + topic_1 *
#     topic_8 + topic_2 * topic_0 + topic_2 * topic_1 + topic_2 *
#     topic_2 + topic_2 * topic_3 + topic_2 * topic_4 + topic_2 *
#     topic_5 + topic_2 * topic_6 + topic_2 * topic_7 + topic_2 *
#     topic_8 + topic_3 * topic_0 + topic_3 * topic_1 + topic_3 *
#     topic_2 + topic_3 * topic_3 + topic_3 * topic_4 + topic_3 *
# ...

# %%
summary(full_model_issues_per_user)
# Out:
# Call:
# lm(formula = issues_per_user ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct + total_contributors +
#     project_age + topic_0 * topic_0 + topic_0 * topic_1 + topic_0 *
#     topic_2 + topic_0 * topic_3 + topic_0 * topic_4 + topic_0 *
#     topic_5 + topic_0 * topic_6 + topic_0 * topic_7 + topic_0 *
#     topic_8 + topic_1 * topic_0 + topic_1 * topic_1 + topic_1 *
#     topic_2 + topic_1 * topic_3 + topic_1 * topic_4 + topic_1 *
#     topic_5 + topic_1 * topic_6 + topic_1 * topic_7 + topic_1 *
#     topic_8 + topic_2 * topic_0 + topic_2 * topic_1 + topic_2 *
#     topic_2 + topic_2 * topic_3 + topic_2 * topic_4 + topic_2 *
#     topic_5 + topic_2 * topic_6 + topic_2 * topic_7 + topic_2 *
#     topic_8 + topic_3 * topic_0 + topic_3 * topic_1 + topic_3 *
#     topic_2 + topic_3 * topic_3 + topic_3 * topic_4 + topic_3 *
# ...
