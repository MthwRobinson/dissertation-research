# %%
library(betareg)
library(MASS)

# %% [markdown]
# ### Beta Regression for Speed Requirements are Addressed

# %%
data = read.csv('/home/matt/research_data_25.csv')
data[data==0] <- .00001

# %% [markdown]
# ### Percent under 30 Days

# %%
res <- betareg(pct_under_30 ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + gini_coefficient 
                              + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct
                              + total_contributors + project_age + topic_0 + topic_1 + topic_2 + topic_3 + topic_4 
                              + topic_5 + topic_6 + topic_7 + topic_8 + topic_9 + topic_10 + topic_11 + topic_12 
                              + topic_13 + topic_14 + topic_15 + topic_16 + topic_17 + topic_18 + topic_19 + topic_20 
                              + topic_21 + topic_22 + topic_23 + topic_0_2 + topic_1_2 + topic_2_2 + topic_3_2 
                              + topic_4_2 + topic_5_2 + topic_6_2 + topic_7_2 + topic_8_2 + topic_9_2 + topic_10_2 
                              + topic_11_2 + topic_12_2 + topic_13_2 + topic_14_2 + topic_15_2 + topic_16_2 + topic_17_2 
                              + topic_18_2 + topic_19_2 + topic_20_2 + topic_21_2 + topic_22_2 + topic_23_2
               , data=data)

# %%
full_model_pct_under_30 <- lm(pct_under_30 ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + gini_coefficient 
                 + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct 
                 + total_contributors + project_age + topic_0*topic_0 + topic_0*topic_1 + topic_0*topic_2 
                 + topic_0*topic_3 + topic_0*topic_4 + topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 
                 + topic_0*topic_8 + topic_0*topic_9 + topic_0*topic_10 + topic_0*topic_11 + topic_0*topic_12
                 + topic_0*topic_13 + topic_0*topic_14 + topic_0*topic_15 + topic_0*topic_16 + topic_0*topic_17 
                 + topic_0*topic_18 + topic_0*topic_19 + topic_0*topic_20 + topic_0*topic_21 + topic_0*topic_22
                 + topic_0*topic_23 + topic_1*topic_0 + topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 
                 + topic_1*topic_4 + topic_1*topic_5 + topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 
                 + topic_1*topic_9 + topic_1*topic_10 + topic_1*topic_11 + topic_1*topic_12 + topic_1*topic_13 
                 + topic_1*topic_14 + topic_1*topic_15 + topic_1*topic_16 + topic_1*topic_17 + topic_1*topic_18 
                 + topic_1*topic_19 + topic_1*topic_20 + topic_1*topic_21 + topic_1*topic_22 + topic_1*topic_23 
                 + topic_2*topic_0 + topic_2*topic_1 + topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 
                 + topic_2*topic_5 + topic_2*topic_6 + topic_2*topic_7 + topic_2*topic_8 + topic_2*topic_9 
                 + topic_2*topic_10 + topic_2*topic_11 + topic_2*topic_12 + topic_2*topic_13 + topic_2*topic_14 
                 + topic_2*topic_15 + topic_2*topic_16 + topic_2*topic_17 + topic_2*topic_18 + topic_2*topic_19 
                 + topic_2*topic_20 + topic_2*topic_21 + topic_2*topic_22 + topic_2*topic_23 + topic_3*topic_0 
                 + topic_3*topic_1 + topic_3*topic_2 + topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 
                 + topic_3*topic_6 + topic_3*topic_7 + topic_3*topic_8 + topic_3*topic_9 + topic_3*topic_10 
                 + topic_3*topic_11 + topic_3*topic_12 + topic_3*topic_13 + topic_3*topic_14 + topic_3*topic_15 
                 + topic_3*topic_16 + topic_3*topic_17 + topic_3*topic_18 + topic_3*topic_19 + topic_3*topic_20 
                 + topic_3*topic_21 + topic_3*topic_22 + topic_3*topic_23 + topic_4*topic_0 + topic_4*topic_1 
                 + topic_4*topic_2 + topic_4*topic_3 + topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 
                 + topic_4*topic_7 + topic_4*topic_8 + topic_4*topic_9 + topic_4*topic_10 + topic_4*topic_11 
                 + topic_4*topic_12 + topic_4*topic_13 + topic_4*topic_14 + topic_4*topic_15 + topic_4*topic_16 
                 + topic_4*topic_17 + topic_4*topic_18 + topic_4*topic_19 + topic_4*topic_20 + topic_4*topic_21 
                 + topic_4*topic_22 + topic_4*topic_23 + topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 
                 + topic_5*topic_3 + topic_5*topic_4 + topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 
                 + topic_5*topic_8 + topic_5*topic_9 + topic_5*topic_10 + topic_5*topic_11 + topic_5*topic_12 
                 + topic_5*topic_13 + topic_5*topic_14 + topic_5*topic_15 + topic_5*topic_16 + topic_5*topic_17 
                 + topic_5*topic_18 + topic_5*topic_19 + topic_5*topic_20 + topic_5*topic_21 + topic_5*topic_22 
                 + topic_5*topic_23 + topic_6*topic_0 + topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 
                 + topic_6*topic_4 + topic_6*topic_5 + topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 
                 + topic_6*topic_9 + topic_6*topic_10 + topic_6*topic_11 + topic_6*topic_12 + topic_6*topic_13 
                 + topic_6*topic_14 + topic_6*topic_15 + topic_6*topic_16 + topic_6*topic_17 + topic_6*topic_18
                 + topic_6*topic_19 + topic_6*topic_20 + topic_6*topic_21 + topic_6*topic_22 + topic_6*topic_23
                 + topic_7*topic_0 + topic_7*topic_1 + topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 
                 + topic_7*topic_5 + topic_7*topic_6 + topic_7*topic_7 + topic_7*topic_8 + topic_7*topic_9 
                 + topic_7*topic_10 + topic_7*topic_11 + topic_7*topic_12 + topic_7*topic_13 + topic_7*topic_14 
                 + topic_7*topic_15 + topic_7*topic_16 + topic_7*topic_17 + topic_7*topic_18 + topic_7*topic_19 
                 + topic_7*topic_20 + topic_7*topic_21 + topic_7*topic_22 + topic_7*topic_23 + topic_8*topic_0 
                 + topic_8*topic_1 + topic_8*topic_2 + topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 
                 + topic_8*topic_7 + topic_8*topic_8 + topic_8*topic_9 + topic_8*topic_10 + topic_8*topic_11 + topic_8*topic_12
                 + topic_8*topic_13 + topic_8*topic_14 + topic_8*topic_15 + topic_8*topic_16 + topic_8*topic_17
                 + topic_8*topic_18 + topic_8*topic_19 + topic_8*topic_20 + topic_8*topic_21 + topic_8*topic_22
                 + topic_8*topic_23 + topic_9*topic_0 + topic_9*topic_1 + topic_9*topic_2 + topic_9*topic_3 
                 + topic_9*topic_4 + topic_9*topic_5 + topic_9*topic_6 + topic_9*topic_7 + topic_9*topic_8 
                 + topic_9*topic_9 + topic_9*topic_10 + topic_9*topic_11 + topic_9*topic_12 + topic_9*topic_13 
                 + topic_9*topic_14 + topic_9*topic_15 + topic_9*topic_16 + topic_9*topic_17 + topic_9*topic_18
                 + topic_9*topic_19 + topic_9*topic_20 + topic_9*topic_21 + topic_9*topic_22 + topic_9*topic_23
                 + topic_10*topic_0 + topic_10*topic_1 + topic_10*topic_2 + topic_10*topic_3 + topic_10*topic_4 
                 + topic_10*topic_5 + topic_10*topic_6 + topic_10*topic_7 + topic_10*topic_8 + topic_10*topic_9 
                 + topic_10*topic_10 + topic_10*topic_11 + topic_10*topic_12 + topic_10*topic_13 + topic_10*topic_14
                 + topic_10*topic_15 + topic_10*topic_16 + topic_10*topic_17 + topic_10*topic_18 + topic_10*topic_19 
                 + topic_10*topic_20 + topic_10*topic_21 + topic_10*topic_22 + topic_10*topic_23 + topic_11*topic_0 
                 + topic_11*topic_1 + topic_11*topic_2 + topic_11*topic_3 + topic_11*topic_4 + topic_11*topic_5 
                 + topic_11*topic_6 + topic_11*topic_7 + topic_11*topic_8 + topic_11*topic_9 + topic_11*topic_10 
                 + topic_11*topic_11 + topic_11*topic_12 + topic_11*topic_13 + topic_11*topic_14 + topic_11*topic_15 
                 + topic_11*topic_16 + topic_11*topic_17 + topic_11*topic_18 + topic_11*topic_19 + topic_11*topic_20 + topic_11*topic_21 + topic_11*topic_22 + topic_11*topic_23 + topic_12*topic_0 + topic_12*topic_1 + topic_12*topic_2 + topic_12*topic_3 + topic_12*topic_4 + topic_12*topic_5 + topic_12*topic_6 + topic_12*topic_7 + topic_12*topic_8 + topic_12*topic_9 + topic_12*topic_10 + topic_12*topic_11 + topic_12*topic_12 + topic_12*topic_13 + topic_12*topic_14 + topic_12*topic_15 + topic_12*topic_16 + topic_12*topic_17 + topic_12*topic_18 + topic_12*topic_19 + topic_12*topic_20 + topic_12*topic_21 + topic_12*topic_22 + topic_12*topic_23 + topic_13*topic_0 + topic_13*topic_1 + topic_13*topic_2 + topic_13*topic_3 + topic_13*topic_4 + topic_13*topic_5 + topic_13*topic_6 + topic_13*topic_7 + topic_13*topic_8 + topic_13*topic_9 + topic_13*topic_10 + topic_13*topic_11 + topic_13*topic_12 + topic_13*topic_13 + topic_13*topic_14 + topic_13*topic_15 + topic_13*topic_16 + topic_13*topic_17 + topic_13*topic_18 + topic_13*topic_19 + topic_13*topic_20 + topic_13*topic_21 + topic_13*topic_22 + topic_13*topic_23 + topic_14*topic_0 + topic_14*topic_1 + topic_14*topic_2 + topic_14*topic_3 + topic_14*topic_4 + topic_14*topic_5 + topic_14*topic_6 + topic_14*topic_7 + topic_14*topic_8 + topic_14*topic_9 + topic_14*topic_10 + topic_14*topic_11 + topic_14*topic_12 + topic_14*topic_13 + topic_14*topic_14 + topic_14*topic_15 + topic_14*topic_16 + topic_14*topic_17 + topic_14*topic_18 + topic_14*topic_19 + topic_14*topic_20 + topic_14*topic_21 + topic_14*topic_22 + topic_14*topic_23 + topic_15*topic_0 + topic_15*topic_1 + topic_15*topic_2 + topic_15*topic_3 + topic_15*topic_4 + topic_15*topic_5 + topic_15*topic_6 + topic_15*topic_7 + topic_15*topic_8 + topic_15*topic_9 + topic_15*topic_10 + topic_15*topic_11 + topic_15*topic_12 + topic_15*topic_13 + topic_15*topic_14 + topic_15*topic_15 + topic_15*topic_16 + topic_15*topic_17 + topic_15*topic_18 + topic_15*topic_19 + topic_15*topic_20 + topic_15*topic_21 + topic_15*topic_22 + topic_15*topic_23 + topic_16*topic_0 + topic_16*topic_1 + topic_16*topic_2 + topic_16*topic_3 + topic_16*topic_4 + topic_16*topic_5 + topic_16*topic_6 + topic_16*topic_7 + topic_16*topic_8 + topic_16*topic_9 + topic_16*topic_10 + topic_16*topic_11 + topic_16*topic_12 + topic_16*topic_13 + topic_16*topic_14 + topic_16*topic_15 + topic_16*topic_16 + topic_16*topic_17 + topic_16*topic_18 + topic_16*topic_19 + topic_16*topic_20 + topic_16*topic_21 + topic_16*topic_22 + topic_16*topic_23 + topic_17*topic_0 + topic_17*topic_1 + topic_17*topic_2 + topic_17*topic_3 + topic_17*topic_4 + topic_17*topic_5 + topic_17*topic_6 + topic_17*topic_7 + topic_17*topic_8 + topic_17*topic_9 + topic_17*topic_10 + topic_17*topic_11 + topic_17*topic_12 + topic_17*topic_13 + topic_17*topic_14 + topic_17*topic_15 + topic_17*topic_16 + topic_17*topic_17 + topic_17*topic_18 + topic_17*topic_19 + topic_17*topic_20 + topic_17*topic_21 + topic_17*topic_22 + topic_17*topic_23 + topic_18*topic_0 + topic_18*topic_1 + topic_18*topic_2 + topic_18*topic_3 + topic_18*topic_4 + topic_18*topic_5 + topic_18*topic_6 + topic_18*topic_7 + topic_18*topic_8 + topic_18*topic_9 + topic_18*topic_10 + topic_18*topic_11 + topic_18*topic_12 + topic_18*topic_13 + topic_18*topic_14 + topic_18*topic_15 + topic_18*topic_16 + topic_18*topic_17 + topic_18*topic_18 + topic_18*topic_19 + topic_18*topic_20 + topic_18*topic_21 + topic_18*topic_22 + topic_18*topic_23 + topic_19*topic_0 + topic_19*topic_1 + topic_19*topic_2 + topic_19*topic_3 + topic_19*topic_4 + topic_19*topic_5 + topic_19*topic_6 + topic_19*topic_7 + topic_19*topic_8 + topic_19*topic_9 + topic_19*topic_10 + topic_19*topic_11 + topic_19*topic_12 + topic_19*topic_13 + topic_19*topic_14 + topic_19*topic_15 + topic_19*topic_16 + topic_19*topic_17 + topic_19*topic_18 + topic_19*topic_19 + topic_19*topic_20 + topic_19*topic_21 + topic_19*topic_22 + topic_19*topic_23 + topic_20*topic_0 + topic_20*topic_1 + topic_20*topic_2 + topic_20*topic_3 + topic_20*topic_4 + topic_20*topic_5 + topic_20*topic_6 + topic_20*topic_7 + topic_20*topic_8 + topic_20*topic_9 + topic_20*topic_10 + topic_20*topic_11 + topic_20*topic_12 + topic_20*topic_13 + topic_20*topic_14 + topic_20*topic_15 + topic_20*topic_16 + topic_20*topic_17 + topic_20*topic_18 + topic_20*topic_19 + topic_20*topic_20 + topic_20*topic_21 + topic_20*topic_22 + topic_20*topic_23 + topic_21*topic_0 + topic_21*topic_1 + topic_21*topic_2 + topic_21*topic_3 + topic_21*topic_4 + topic_21*topic_5 + topic_21*topic_6 + topic_21*topic_7 + topic_21*topic_8 + topic_21*topic_9 + topic_21*topic_10 + topic_21*topic_11 + topic_21*topic_12 + topic_21*topic_13 + topic_21*topic_14 + topic_21*topic_15 + topic_21*topic_16 + topic_21*topic_17 + topic_21*topic_18 + topic_21*topic_19 + topic_21*topic_20 + topic_21*topic_21 + topic_21*topic_22 + topic_21*topic_23 + topic_22*topic_0 + topic_22*topic_1 + topic_22*topic_2 + topic_22*topic_3 + topic_22*topic_4 + topic_22*topic_5 + topic_22*topic_6 + topic_22*topic_7 + topic_22*topic_8 + topic_22*topic_9 + topic_22*topic_10 + topic_22*topic_11 + topic_22*topic_12 + topic_22*topic_13 + topic_22*topic_14 + topic_22*topic_15 + topic_22*topic_16 + topic_22*topic_17 + topic_22*topic_18 + topic_22*topic_19 + topic_22*topic_20 + topic_22*topic_21 + topic_22*topic_22 + topic_22*topic_23 + topic_23*topic_0 + topic_23*topic_1 + topic_23*topic_2 + topic_23*topic_3 + topic_23*topic_4 + topic_23*topic_5 + topic_23*topic_6 + topic_23*topic_7 + topic_23*topic_8 + topic_23*topic_9 + topic_23*topic_10 + topic_23*topic_11 
                 + topic_23*topic_12 + topic_23*topic_13 + topic_23*topic_14 + topic_23*topic_15 + topic_23*topic_16 
                 + topic_23*topic_17 + topic_23*topic_18 + topic_23*topic_19 + topic_23*topic_20 + topic_23*topic_21 
                 + topic_23*topic_22 + topic_23*topic_23
, data = data)
# Stepwise regression model
step_model_pct_under_30 <- stepAIC(full_model_pct_under_30, direction = "both", trace = FALSE)
summary(step_model_pct_under_30)
# Out:
# Call:
# lm(formula = pct_under_30 ~ crowd_pct_2 + avg_clustering + gini_coefficient +
#     avg_min_pathXcrowd_pct + project_age + topic_0 + topic_1 +
#     topic_2 + topic_3 + topic_4 + topic_5 + topic_6 + topic_7 +
#     topic_8 + topic_9 + topic_10 + topic_11 + topic_12 + topic_13 +
#     topic_14 + topic_15 + topic_16 + topic_17 + topic_18 + topic_19 +
#     topic_20 + topic_21 + topic_22 + topic_23 + topic_0:topic_6 +
#     topic_0:topic_7 + topic_0:topic_8 + topic_0:topic_18 + topic_0:topic_20 +
#     topic_0:topic_22 + topic_0:topic_23 + topic_1:topic_10 +
#     topic_1:topic_11 + topic_1:topic_13 + topic_1:topic_14 +
#     topic_1:topic_17 + topic_1:topic_20 + topic_1:topic_22 +
#     topic_2:topic_4 + topic_2:topic_10 + topic_2:topic_16 + topic_2:topic_17 +
#     topic_2:topic_18 + topic_2:topic_22 + topic_3:topic_4 + topic_3:topic_9 +
#     topic_3:topic_10 + topic_3:topic_13 + topic_3:topic_15 +
#     topic_3:topic_16 + topic_3:topic_21 + topic_3:topic_22 +
# ...

# %% [markdown]
# ### Average Number of Comments

# %%
full_model_avg_comments <- lm(avg_comments ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + gini_coefficient 
                 + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct 
                 + total_contributors + project_age + topic_0*topic_0 + topic_0*topic_1 + topic_0*topic_2 
                 + topic_0*topic_3 + topic_0*topic_4 + topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 
                 + topic_0*topic_8 + topic_0*topic_9 + topic_0*topic_10 + topic_0*topic_11 + topic_0*topic_12
                 + topic_0*topic_13 + topic_0*topic_14 + topic_0*topic_15 + topic_0*topic_16 + topic_0*topic_17 
                 + topic_0*topic_18 + topic_0*topic_19 + topic_0*topic_20 + topic_0*topic_21 + topic_0*topic_22
                 + topic_0*topic_23 + topic_1*topic_0 + topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 
                 + topic_1*topic_4 + topic_1*topic_5 + topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 
                 + topic_1*topic_9 + topic_1*topic_10 + topic_1*topic_11 + topic_1*topic_12 + topic_1*topic_13 
                 + topic_1*topic_14 + topic_1*topic_15 + topic_1*topic_16 + topic_1*topic_17 + topic_1*topic_18 
                 + topic_1*topic_19 + topic_1*topic_20 + topic_1*topic_21 + topic_1*topic_22 + topic_1*topic_23 
                 + topic_2*topic_0 + topic_2*topic_1 + topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 
                 + topic_2*topic_5 + topic_2*topic_6 + topic_2*topic_7 + topic_2*topic_8 + topic_2*topic_9 
                 + topic_2*topic_10 + topic_2*topic_11 + topic_2*topic_12 + topic_2*topic_13 + topic_2*topic_14 
                 + topic_2*topic_15 + topic_2*topic_16 + topic_2*topic_17 + topic_2*topic_18 + topic_2*topic_19 
                 + topic_2*topic_20 + topic_2*topic_21 + topic_2*topic_22 + topic_2*topic_23 + topic_3*topic_0 
                 + topic_3*topic_1 + topic_3*topic_2 + topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 
                 + topic_3*topic_6 + topic_3*topic_7 + topic_3*topic_8 + topic_3*topic_9 + topic_3*topic_10 
                 + topic_3*topic_11 + topic_3*topic_12 + topic_3*topic_13 + topic_3*topic_14 + topic_3*topic_15 
                 + topic_3*topic_16 + topic_3*topic_17 + topic_3*topic_18 + topic_3*topic_19 + topic_3*topic_20 
                 + topic_3*topic_21 + topic_3*topic_22 + topic_3*topic_23 + topic_4*topic_0 + topic_4*topic_1 
                 + topic_4*topic_2 + topic_4*topic_3 + topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 
                 + topic_4*topic_7 + topic_4*topic_8 + topic_4*topic_9 + topic_4*topic_10 + topic_4*topic_11 
                 + topic_4*topic_12 + topic_4*topic_13 + topic_4*topic_14 + topic_4*topic_15 + topic_4*topic_16 
                 + topic_4*topic_17 + topic_4*topic_18 + topic_4*topic_19 + topic_4*topic_20 + topic_4*topic_21 
                 + topic_4*topic_22 + topic_4*topic_23 + topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 
                 + topic_5*topic_3 + topic_5*topic_4 + topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 
                 + topic_5*topic_8 + topic_5*topic_9 + topic_5*topic_10 + topic_5*topic_11 + topic_5*topic_12 
                 + topic_5*topic_13 + topic_5*topic_14 + topic_5*topic_15 + topic_5*topic_16 + topic_5*topic_17 
                 + topic_5*topic_18 + topic_5*topic_19 + topic_5*topic_20 + topic_5*topic_21 + topic_5*topic_22 
                 + topic_5*topic_23 + topic_6*topic_0 + topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 
                 + topic_6*topic_4 + topic_6*topic_5 + topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 
                 + topic_6*topic_9 + topic_6*topic_10 + topic_6*topic_11 + topic_6*topic_12 + topic_6*topic_13 
                 + topic_6*topic_14 + topic_6*topic_15 + topic_6*topic_16 + topic_6*topic_17 + topic_6*topic_18
                 + topic_6*topic_19 + topic_6*topic_20 + topic_6*topic_21 + topic_6*topic_22 + topic_6*topic_23
                 + topic_7*topic_0 + topic_7*topic_1 + topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 
                 + topic_7*topic_5 + topic_7*topic_6 + topic_7*topic_7 + topic_7*topic_8 + topic_7*topic_9 
                 + topic_7*topic_10 + topic_7*topic_11 + topic_7*topic_12 + topic_7*topic_13 + topic_7*topic_14 
                 + topic_7*topic_15 + topic_7*topic_16 + topic_7*topic_17 + topic_7*topic_18 + topic_7*topic_19 
                 + topic_7*topic_20 + topic_7*topic_21 + topic_7*topic_22 + topic_7*topic_23 + topic_8*topic_0 
                 + topic_8*topic_1 + topic_8*topic_2 + topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 
                 + topic_8*topic_7 + topic_8*topic_8 + topic_8*topic_9 + topic_8*topic_10 + topic_8*topic_11 + topic_8*topic_12
                 + topic_8*topic_13 + topic_8*topic_14 + topic_8*topic_15 + topic_8*topic_16 + topic_8*topic_17
                 + topic_8*topic_18 + topic_8*topic_19 + topic_8*topic_20 + topic_8*topic_21 + topic_8*topic_22
                 + topic_8*topic_23 + topic_9*topic_0 + topic_9*topic_1 + topic_9*topic_2 + topic_9*topic_3 
                 + topic_9*topic_4 + topic_9*topic_5 + topic_9*topic_6 + topic_9*topic_7 + topic_9*topic_8 
                 + topic_9*topic_9 + topic_9*topic_10 + topic_9*topic_11 + topic_9*topic_12 + topic_9*topic_13 
                 + topic_9*topic_14 + topic_9*topic_15 + topic_9*topic_16 + topic_9*topic_17 + topic_9*topic_18
                 + topic_9*topic_19 + topic_9*topic_20 + topic_9*topic_21 + topic_9*topic_22 + topic_9*topic_23
                 + topic_10*topic_0 + topic_10*topic_1 + topic_10*topic_2 + topic_10*topic_3 + topic_10*topic_4 
                 + topic_10*topic_5 + topic_10*topic_6 + topic_10*topic_7 + topic_10*topic_8 + topic_10*topic_9 
                 + topic_10*topic_10 + topic_10*topic_11 + topic_10*topic_12 + topic_10*topic_13 + topic_10*topic_14
                 + topic_10*topic_15 + topic_10*topic_16 + topic_10*topic_17 + topic_10*topic_18 + topic_10*topic_19 
                 + topic_10*topic_20 + topic_10*topic_21 + topic_10*topic_22 + topic_10*topic_23 + topic_11*topic_0 
                 + topic_11*topic_1 + topic_11*topic_2 + topic_11*topic_3 + topic_11*topic_4 + topic_11*topic_5 
                 + topic_11*topic_6 + topic_11*topic_7 + topic_11*topic_8 + topic_11*topic_9 + topic_11*topic_10 
                 + topic_11*topic_11 + topic_11*topic_12 + topic_11*topic_13 + topic_11*topic_14 + topic_11*topic_15 
                 + topic_11*topic_16 + topic_11*topic_17 + topic_11*topic_18 + topic_11*topic_19 + topic_11*topic_20 + topic_11*topic_21 + topic_11*topic_22 + topic_11*topic_23 + topic_12*topic_0 + topic_12*topic_1 + topic_12*topic_2 + topic_12*topic_3 + topic_12*topic_4 + topic_12*topic_5 + topic_12*topic_6 + topic_12*topic_7 + topic_12*topic_8 + topic_12*topic_9 + topic_12*topic_10 + topic_12*topic_11 + topic_12*topic_12 + topic_12*topic_13 + topic_12*topic_14 + topic_12*topic_15 + topic_12*topic_16 + topic_12*topic_17 + topic_12*topic_18 + topic_12*topic_19 + topic_12*topic_20 + topic_12*topic_21 + topic_12*topic_22 + topic_12*topic_23 + topic_13*topic_0 + topic_13*topic_1 + topic_13*topic_2 + topic_13*topic_3 + topic_13*topic_4 + topic_13*topic_5 + topic_13*topic_6 + topic_13*topic_7 + topic_13*topic_8 + topic_13*topic_9 + topic_13*topic_10 + topic_13*topic_11 + topic_13*topic_12 + topic_13*topic_13 + topic_13*topic_14 + topic_13*topic_15 + topic_13*topic_16 + topic_13*topic_17 + topic_13*topic_18 + topic_13*topic_19 + topic_13*topic_20 + topic_13*topic_21 + topic_13*topic_22 + topic_13*topic_23 + topic_14*topic_0 + topic_14*topic_1 + topic_14*topic_2 + topic_14*topic_3 + topic_14*topic_4 + topic_14*topic_5 + topic_14*topic_6 + topic_14*topic_7 + topic_14*topic_8 + topic_14*topic_9 + topic_14*topic_10 + topic_14*topic_11 + topic_14*topic_12 + topic_14*topic_13 + topic_14*topic_14 + topic_14*topic_15 + topic_14*topic_16 + topic_14*topic_17 + topic_14*topic_18 + topic_14*topic_19 + topic_14*topic_20 + topic_14*topic_21 + topic_14*topic_22 + topic_14*topic_23 + topic_15*topic_0 + topic_15*topic_1 + topic_15*topic_2 + topic_15*topic_3 + topic_15*topic_4 + topic_15*topic_5 + topic_15*topic_6 + topic_15*topic_7 + topic_15*topic_8 + topic_15*topic_9 + topic_15*topic_10 + topic_15*topic_11 + topic_15*topic_12 + topic_15*topic_13 + topic_15*topic_14 + topic_15*topic_15 + topic_15*topic_16 + topic_15*topic_17 + topic_15*topic_18 + topic_15*topic_19 + topic_15*topic_20 + topic_15*topic_21 + topic_15*topic_22 + topic_15*topic_23 + topic_16*topic_0 + topic_16*topic_1 + topic_16*topic_2 + topic_16*topic_3 + topic_16*topic_4 + topic_16*topic_5 + topic_16*topic_6 + topic_16*topic_7 + topic_16*topic_8 + topic_16*topic_9 + topic_16*topic_10 + topic_16*topic_11 + topic_16*topic_12 + topic_16*topic_13 + topic_16*topic_14 + topic_16*topic_15 + topic_16*topic_16 + topic_16*topic_17 + topic_16*topic_18 + topic_16*topic_19 + topic_16*topic_20 + topic_16*topic_21 + topic_16*topic_22 + topic_16*topic_23 + topic_17*topic_0 + topic_17*topic_1 + topic_17*topic_2 + topic_17*topic_3 + topic_17*topic_4 + topic_17*topic_5 + topic_17*topic_6 + topic_17*topic_7 + topic_17*topic_8 + topic_17*topic_9 + topic_17*topic_10 + topic_17*topic_11 + topic_17*topic_12 + topic_17*topic_13 + topic_17*topic_14 + topic_17*topic_15 + topic_17*topic_16 + topic_17*topic_17 + topic_17*topic_18 + topic_17*topic_19 + topic_17*topic_20 + topic_17*topic_21 + topic_17*topic_22 + topic_17*topic_23 + topic_18*topic_0 + topic_18*topic_1 + topic_18*topic_2 + topic_18*topic_3 + topic_18*topic_4 + topic_18*topic_5 + topic_18*topic_6 + topic_18*topic_7 + topic_18*topic_8 + topic_18*topic_9 + topic_18*topic_10 + topic_18*topic_11 + topic_18*topic_12 + topic_18*topic_13 + topic_18*topic_14 + topic_18*topic_15 + topic_18*topic_16 + topic_18*topic_17 + topic_18*topic_18 + topic_18*topic_19 + topic_18*topic_20 + topic_18*topic_21 + topic_18*topic_22 + topic_18*topic_23 + topic_19*topic_0 + topic_19*topic_1 + topic_19*topic_2 + topic_19*topic_3 + topic_19*topic_4 + topic_19*topic_5 + topic_19*topic_6 + topic_19*topic_7 + topic_19*topic_8 + topic_19*topic_9 + topic_19*topic_10 + topic_19*topic_11 + topic_19*topic_12 + topic_19*topic_13 + topic_19*topic_14 + topic_19*topic_15 + topic_19*topic_16 + topic_19*topic_17 + topic_19*topic_18 + topic_19*topic_19 + topic_19*topic_20 + topic_19*topic_21 + topic_19*topic_22 + topic_19*topic_23 + topic_20*topic_0 + topic_20*topic_1 + topic_20*topic_2 + topic_20*topic_3 + topic_20*topic_4 + topic_20*topic_5 + topic_20*topic_6 + topic_20*topic_7 + topic_20*topic_8 + topic_20*topic_9 + topic_20*topic_10 + topic_20*topic_11 + topic_20*topic_12 + topic_20*topic_13 + topic_20*topic_14 + topic_20*topic_15 + topic_20*topic_16 + topic_20*topic_17 + topic_20*topic_18 + topic_20*topic_19 + topic_20*topic_20 + topic_20*topic_21 + topic_20*topic_22 + topic_20*topic_23 + topic_21*topic_0 + topic_21*topic_1 + topic_21*topic_2 + topic_21*topic_3 + topic_21*topic_4 + topic_21*topic_5 + topic_21*topic_6 + topic_21*topic_7 + topic_21*topic_8 + topic_21*topic_9 + topic_21*topic_10 + topic_21*topic_11 + topic_21*topic_12 + topic_21*topic_13 + topic_21*topic_14 + topic_21*topic_15 + topic_21*topic_16 + topic_21*topic_17 + topic_21*topic_18 + topic_21*topic_19 + topic_21*topic_20 + topic_21*topic_21 + topic_21*topic_22 + topic_21*topic_23 + topic_22*topic_0 + topic_22*topic_1 + topic_22*topic_2 + topic_22*topic_3 + topic_22*topic_4 + topic_22*topic_5 + topic_22*topic_6 + topic_22*topic_7 + topic_22*topic_8 + topic_22*topic_9 + topic_22*topic_10 + topic_22*topic_11 + topic_22*topic_12 + topic_22*topic_13 + topic_22*topic_14 + topic_22*topic_15 + topic_22*topic_16 + topic_22*topic_17 + topic_22*topic_18 + topic_22*topic_19 + topic_22*topic_20 + topic_22*topic_21 + topic_22*topic_22 + topic_22*topic_23 + topic_23*topic_0 + topic_23*topic_1 + topic_23*topic_2 + topic_23*topic_3 + topic_23*topic_4 + topic_23*topic_5 + topic_23*topic_6 + topic_23*topic_7 + topic_23*topic_8 + topic_23*topic_9 + topic_23*topic_10 + topic_23*topic_11 
                 + topic_23*topic_12 + topic_23*topic_13 + topic_23*topic_14 + topic_23*topic_15 + topic_23*topic_16 
                 + topic_23*topic_17 + topic_23*topic_18 + topic_23*topic_19 + topic_23*topic_20 + topic_23*topic_21 
                 + topic_23*topic_22 + topic_23*topic_23
, data = data)
# Stepwise regression model
step_model_avg_comments <- stepAIC(full_model_avg_comments, direction = "both", 
                      trace = FALSE)
summary(step_model_avg_comments)
# Out:
# Call:
# lm(formula = avg_comments ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct + project_age +
#     topic_0 + topic_1 + topic_2 + topic_3 + topic_4 + topic_5 +
#     topic_6 + topic_7 + topic_8 + topic_9 + topic_10 + topic_11 +
#     topic_12 + topic_13 + topic_14 + topic_15 + topic_16 + topic_17 +
#     topic_18 + topic_19 + topic_20 + topic_21 + topic_22 + topic_23 +
#     topic_0:topic_1 + topic_0:topic_7 + topic_0:topic_9 + topic_0:topic_10 +
#     topic_0:topic_18 + topic_0:topic_19 + topic_0:topic_21 +
#     topic_1:topic_2 + topic_1:topic_9 + topic_1:topic_10 + topic_1:topic_13 +
#     topic_1:topic_14 + topic_1:topic_21 + topic_2:topic_11 +
#     topic_2:topic_12 + topic_2:topic_18 + topic_2:topic_20 +
#     topic_2:topic_22 + topic_3:topic_5 + topic_3:topic_11 + topic_3:topic_21 +
# ...

# %% [markdown]
# ### Issue Volume

# %%
full_model_volume <- lm(issues_over_time ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + gini_coefficient 
                 + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct 
                 + total_contributors + project_age + topic_0*topic_0 + topic_0*topic_1 + topic_0*topic_2 
                 + topic_0*topic_3 + topic_0*topic_4 + topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 
                 + topic_0*topic_8 + topic_0*topic_9 + topic_0*topic_10 + topic_0*topic_11 + topic_0*topic_12
                 + topic_0*topic_13 + topic_0*topic_14 + topic_0*topic_15 + topic_0*topic_16 + topic_0*topic_17 
                 + topic_0*topic_18 + topic_0*topic_19 + topic_0*topic_20 + topic_0*topic_21 + topic_0*topic_22
                 + topic_0*topic_23 + topic_1*topic_0 + topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 
                 + topic_1*topic_4 + topic_1*topic_5 + topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 
                 + topic_1*topic_9 + topic_1*topic_10 + topic_1*topic_11 + topic_1*topic_12 + topic_1*topic_13 
                 + topic_1*topic_14 + topic_1*topic_15 + topic_1*topic_16 + topic_1*topic_17 + topic_1*topic_18 
                 + topic_1*topic_19 + topic_1*topic_20 + topic_1*topic_21 + topic_1*topic_22 + topic_1*topic_23 
                 + topic_2*topic_0 + topic_2*topic_1 + topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 
                 + topic_2*topic_5 + topic_2*topic_6 + topic_2*topic_7 + topic_2*topic_8 + topic_2*topic_9 
                 + topic_2*topic_10 + topic_2*topic_11 + topic_2*topic_12 + topic_2*topic_13 + topic_2*topic_14 
                 + topic_2*topic_15 + topic_2*topic_16 + topic_2*topic_17 + topic_2*topic_18 + topic_2*topic_19 
                 + topic_2*topic_20 + topic_2*topic_21 + topic_2*topic_22 + topic_2*topic_23 + topic_3*topic_0 
                 + topic_3*topic_1 + topic_3*topic_2 + topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 
                 + topic_3*topic_6 + topic_3*topic_7 + topic_3*topic_8 + topic_3*topic_9 + topic_3*topic_10 
                 + topic_3*topic_11 + topic_3*topic_12 + topic_3*topic_13 + topic_3*topic_14 + topic_3*topic_15 
                 + topic_3*topic_16 + topic_3*topic_17 + topic_3*topic_18 + topic_3*topic_19 + topic_3*topic_20 
                 + topic_3*topic_21 + topic_3*topic_22 + topic_3*topic_23 + topic_4*topic_0 + topic_4*topic_1 
                 + topic_4*topic_2 + topic_4*topic_3 + topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 
                 + topic_4*topic_7 + topic_4*topic_8 + topic_4*topic_9 + topic_4*topic_10 + topic_4*topic_11 
                 + topic_4*topic_12 + topic_4*topic_13 + topic_4*topic_14 + topic_4*topic_15 + topic_4*topic_16 
                 + topic_4*topic_17 + topic_4*topic_18 + topic_4*topic_19 + topic_4*topic_20 + topic_4*topic_21 
                 + topic_4*topic_22 + topic_4*topic_23 + topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 
                 + topic_5*topic_3 + topic_5*topic_4 + topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 
                 + topic_5*topic_8 + topic_5*topic_9 + topic_5*topic_10 + topic_5*topic_11 + topic_5*topic_12 
                 + topic_5*topic_13 + topic_5*topic_14 + topic_5*topic_15 + topic_5*topic_16 + topic_5*topic_17 
                 + topic_5*topic_18 + topic_5*topic_19 + topic_5*topic_20 + topic_5*topic_21 + topic_5*topic_22 
                 + topic_5*topic_23 + topic_6*topic_0 + topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 
                 + topic_6*topic_4 + topic_6*topic_5 + topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 
                 + topic_6*topic_9 + topic_6*topic_10 + topic_6*topic_11 + topic_6*topic_12 + topic_6*topic_13 
                 + topic_6*topic_14 + topic_6*topic_15 + topic_6*topic_16 + topic_6*topic_17 + topic_6*topic_18
                 + topic_6*topic_19 + topic_6*topic_20 + topic_6*topic_21 + topic_6*topic_22 + topic_6*topic_23
                 + topic_7*topic_0 + topic_7*topic_1 + topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 
                 + topic_7*topic_5 + topic_7*topic_6 + topic_7*topic_7 + topic_7*topic_8 + topic_7*topic_9 
                 + topic_7*topic_10 + topic_7*topic_11 + topic_7*topic_12 + topic_7*topic_13 + topic_7*topic_14 
                 + topic_7*topic_15 + topic_7*topic_16 + topic_7*topic_17 + topic_7*topic_18 + topic_7*topic_19 
                 + topic_7*topic_20 + topic_7*topic_21 + topic_7*topic_22 + topic_7*topic_23 + topic_8*topic_0 
                 + topic_8*topic_1 + topic_8*topic_2 + topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 
                 + topic_8*topic_7 + topic_8*topic_8 + topic_8*topic_9 + topic_8*topic_10 + topic_8*topic_11 + topic_8*topic_12
                 + topic_8*topic_13 + topic_8*topic_14 + topic_8*topic_15 + topic_8*topic_16 + topic_8*topic_17
                 + topic_8*topic_18 + topic_8*topic_19 + topic_8*topic_20 + topic_8*topic_21 + topic_8*topic_22
                 + topic_8*topic_23 + topic_9*topic_0 + topic_9*topic_1 + topic_9*topic_2 + topic_9*topic_3 
                 + topic_9*topic_4 + topic_9*topic_5 + topic_9*topic_6 + topic_9*topic_7 + topic_9*topic_8 
                 + topic_9*topic_9 + topic_9*topic_10 + topic_9*topic_11 + topic_9*topic_12 + topic_9*topic_13 
                 + topic_9*topic_14 + topic_9*topic_15 + topic_9*topic_16 + topic_9*topic_17 + topic_9*topic_18
                 + topic_9*topic_19 + topic_9*topic_20 + topic_9*topic_21 + topic_9*topic_22 + topic_9*topic_23
                 + topic_10*topic_0 + topic_10*topic_1 + topic_10*topic_2 + topic_10*topic_3 + topic_10*topic_4 
                 + topic_10*topic_5 + topic_10*topic_6 + topic_10*topic_7 + topic_10*topic_8 + topic_10*topic_9 
                 + topic_10*topic_10 + topic_10*topic_11 + topic_10*topic_12 + topic_10*topic_13 + topic_10*topic_14
                 + topic_10*topic_15 + topic_10*topic_16 + topic_10*topic_17 + topic_10*topic_18 + topic_10*topic_19 
                 + topic_10*topic_20 + topic_10*topic_21 + topic_10*topic_22 + topic_10*topic_23 + topic_11*topic_0 
                 + topic_11*topic_1 + topic_11*topic_2 + topic_11*topic_3 + topic_11*topic_4 + topic_11*topic_5 
                 + topic_11*topic_6 + topic_11*topic_7 + topic_11*topic_8 + topic_11*topic_9 + topic_11*topic_10 
                 + topic_11*topic_11 + topic_11*topic_12 + topic_11*topic_13 + topic_11*topic_14 + topic_11*topic_15 
                 + topic_11*topic_16 + topic_11*topic_17 + topic_11*topic_18 + topic_11*topic_19 + topic_11*topic_20 + topic_11*topic_21 + topic_11*topic_22 + topic_11*topic_23 + topic_12*topic_0 + topic_12*topic_1 + topic_12*topic_2 + topic_12*topic_3 + topic_12*topic_4 + topic_12*topic_5 + topic_12*topic_6 + topic_12*topic_7 + topic_12*topic_8 + topic_12*topic_9 + topic_12*topic_10 + topic_12*topic_11 + topic_12*topic_12 + topic_12*topic_13 + topic_12*topic_14 + topic_12*topic_15 + topic_12*topic_16 + topic_12*topic_17 + topic_12*topic_18 + topic_12*topic_19 + topic_12*topic_20 + topic_12*topic_21 + topic_12*topic_22 + topic_12*topic_23 + topic_13*topic_0 + topic_13*topic_1 + topic_13*topic_2 + topic_13*topic_3 + topic_13*topic_4 + topic_13*topic_5 + topic_13*topic_6 + topic_13*topic_7 + topic_13*topic_8 + topic_13*topic_9 + topic_13*topic_10 + topic_13*topic_11 + topic_13*topic_12 + topic_13*topic_13 + topic_13*topic_14 + topic_13*topic_15 + topic_13*topic_16 + topic_13*topic_17 + topic_13*topic_18 + topic_13*topic_19 + topic_13*topic_20 + topic_13*topic_21 + topic_13*topic_22 + topic_13*topic_23 + topic_14*topic_0 + topic_14*topic_1 + topic_14*topic_2 + topic_14*topic_3 + topic_14*topic_4 + topic_14*topic_5 + topic_14*topic_6 + topic_14*topic_7 + topic_14*topic_8 + topic_14*topic_9 + topic_14*topic_10 + topic_14*topic_11 + topic_14*topic_12 + topic_14*topic_13 + topic_14*topic_14 + topic_14*topic_15 + topic_14*topic_16 + topic_14*topic_17 + topic_14*topic_18 + topic_14*topic_19 + topic_14*topic_20 + topic_14*topic_21 + topic_14*topic_22 + topic_14*topic_23 + topic_15*topic_0 + topic_15*topic_1 + topic_15*topic_2 + topic_15*topic_3 + topic_15*topic_4 + topic_15*topic_5 + topic_15*topic_6 + topic_15*topic_7 + topic_15*topic_8 + topic_15*topic_9 + topic_15*topic_10 + topic_15*topic_11 + topic_15*topic_12 + topic_15*topic_13 + topic_15*topic_14 + topic_15*topic_15 + topic_15*topic_16 + topic_15*topic_17 + topic_15*topic_18 + topic_15*topic_19 + topic_15*topic_20 + topic_15*topic_21 + topic_15*topic_22 + topic_15*topic_23 + topic_16*topic_0 + topic_16*topic_1 + topic_16*topic_2 + topic_16*topic_3 + topic_16*topic_4 + topic_16*topic_5 + topic_16*topic_6 + topic_16*topic_7 + topic_16*topic_8 + topic_16*topic_9 + topic_16*topic_10 + topic_16*topic_11 + topic_16*topic_12 + topic_16*topic_13 + topic_16*topic_14 + topic_16*topic_15 + topic_16*topic_16 + topic_16*topic_17 + topic_16*topic_18 + topic_16*topic_19 + topic_16*topic_20 + topic_16*topic_21 + topic_16*topic_22 + topic_16*topic_23 + topic_17*topic_0 + topic_17*topic_1 + topic_17*topic_2 + topic_17*topic_3 + topic_17*topic_4 + topic_17*topic_5 + topic_17*topic_6 + topic_17*topic_7 + topic_17*topic_8 + topic_17*topic_9 + topic_17*topic_10 + topic_17*topic_11 + topic_17*topic_12 + topic_17*topic_13 + topic_17*topic_14 + topic_17*topic_15 + topic_17*topic_16 + topic_17*topic_17 + topic_17*topic_18 + topic_17*topic_19 + topic_17*topic_20 + topic_17*topic_21 + topic_17*topic_22 + topic_17*topic_23 + topic_18*topic_0 + topic_18*topic_1 + topic_18*topic_2 + topic_18*topic_3 + topic_18*topic_4 + topic_18*topic_5 + topic_18*topic_6 + topic_18*topic_7 + topic_18*topic_8 + topic_18*topic_9 + topic_18*topic_10 + topic_18*topic_11 + topic_18*topic_12 + topic_18*topic_13 + topic_18*topic_14 + topic_18*topic_15 + topic_18*topic_16 + topic_18*topic_17 + topic_18*topic_18 + topic_18*topic_19 + topic_18*topic_20 + topic_18*topic_21 + topic_18*topic_22 + topic_18*topic_23 + topic_19*topic_0 + topic_19*topic_1 + topic_19*topic_2 + topic_19*topic_3 + topic_19*topic_4 + topic_19*topic_5 + topic_19*topic_6 + topic_19*topic_7 + topic_19*topic_8 + topic_19*topic_9 + topic_19*topic_10 + topic_19*topic_11 + topic_19*topic_12 + topic_19*topic_13 + topic_19*topic_14 + topic_19*topic_15 + topic_19*topic_16 + topic_19*topic_17 + topic_19*topic_18 + topic_19*topic_19 + topic_19*topic_20 + topic_19*topic_21 + topic_19*topic_22 + topic_19*topic_23 + topic_20*topic_0 + topic_20*topic_1 + topic_20*topic_2 + topic_20*topic_3 + topic_20*topic_4 + topic_20*topic_5 + topic_20*topic_6 + topic_20*topic_7 + topic_20*topic_8 + topic_20*topic_9 + topic_20*topic_10 + topic_20*topic_11 + topic_20*topic_12 + topic_20*topic_13 + topic_20*topic_14 + topic_20*topic_15 + topic_20*topic_16 + topic_20*topic_17 + topic_20*topic_18 + topic_20*topic_19 + topic_20*topic_20 + topic_20*topic_21 + topic_20*topic_22 + topic_20*topic_23 + topic_21*topic_0 + topic_21*topic_1 + topic_21*topic_2 + topic_21*topic_3 + topic_21*topic_4 + topic_21*topic_5 + topic_21*topic_6 + topic_21*topic_7 + topic_21*topic_8 + topic_21*topic_9 + topic_21*topic_10 + topic_21*topic_11 + topic_21*topic_12 + topic_21*topic_13 + topic_21*topic_14 + topic_21*topic_15 + topic_21*topic_16 + topic_21*topic_17 + topic_21*topic_18 + topic_21*topic_19 + topic_21*topic_20 + topic_21*topic_21 + topic_21*topic_22 + topic_21*topic_23 + topic_22*topic_0 + topic_22*topic_1 + topic_22*topic_2 + topic_22*topic_3 + topic_22*topic_4 + topic_22*topic_5 + topic_22*topic_6 + topic_22*topic_7 + topic_22*topic_8 + topic_22*topic_9 + topic_22*topic_10 + topic_22*topic_11 + topic_22*topic_12 + topic_22*topic_13 + topic_22*topic_14 + topic_22*topic_15 + topic_22*topic_16 + topic_22*topic_17 + topic_22*topic_18 + topic_22*topic_19 + topic_22*topic_20 + topic_22*topic_21 + topic_22*topic_22 + topic_22*topic_23 + topic_23*topic_0 + topic_23*topic_1 + topic_23*topic_2 + topic_23*topic_3 + topic_23*topic_4 + topic_23*topic_5 + topic_23*topic_6 + topic_23*topic_7 + topic_23*topic_8 + topic_23*topic_9 + topic_23*topic_10 + topic_23*topic_11 
                 + topic_23*topic_12 + topic_23*topic_13 + topic_23*topic_14 + topic_23*topic_15 + topic_23*topic_16 
                 + topic_23*topic_17 + topic_23*topic_18 + topic_23*topic_19 + topic_23*topic_20 + topic_23*topic_21 
                 + topic_23*topic_22 + topic_23*topic_23
, data = data)
# Stepwise regression model
step_model_volume <- stepAIC(full_model_volume, direction = "both", 
                      trace = FALSE)
summary(step_model_volume)
# Out:
# Call:
# lm(formula = issues_over_time ~ crowd_pct_2 + avg_clustering +
#     gini_coefficient + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct +
#     gini_coefficientXcrowd_pct + total_contributors + project_age +
#     topic_0 + topic_1 + topic_2 + topic_3 + topic_4 + topic_5 +
#     topic_6 + topic_7 + topic_8 + topic_9 + topic_10 + topic_11 +
#     topic_12 + topic_13 + topic_14 + topic_15 + topic_16 + topic_17 +
#     topic_18 + topic_19 + topic_20 + topic_21 + topic_22 + topic_23 +
#     avg_min_path + topic_0:topic_1 + topic_0:topic_2 + topic_0:topic_3 +
#     topic_0:topic_5 + topic_0:topic_6 + topic_0:topic_7 + topic_0:topic_9 +
#     topic_0:topic_10 + topic_0:topic_11 + topic_0:topic_13 +
#     topic_0:topic_14 + topic_0:topic_15 + topic_0:topic_16 +
#     topic_0:topic_17 + topic_0:topic_18 + topic_0:topic_20 +
#     topic_0:topic_22 + topic_0:topic_23 + topic_1:topic_2 + topic_1:topic_4 +
#     topic_1:topic_5 + topic_1:topic_6 + topic_1:topic_10 + topic_1:topic_12 +
# ...

# %% [markdown]
# ### Average Response Time

# %%
full_model_first_comment <- lm(avg_first_comment ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + gini_coefficient 
                 + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct 
                 + total_contributors + project_age + topic_0*topic_0 + topic_0*topic_1 + topic_0*topic_2 
                 + topic_0*topic_3 + topic_0*topic_4 + topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 
                 + topic_0*topic_8 + topic_0*topic_9 + topic_0*topic_10 + topic_0*topic_11 + topic_0*topic_12
                 + topic_0*topic_13 + topic_0*topic_14 + topic_0*topic_15 + topic_0*topic_16 + topic_0*topic_17 
                 + topic_0*topic_18 + topic_0*topic_19 + topic_0*topic_20 + topic_0*topic_21 + topic_0*topic_22
                 + topic_0*topic_23 + topic_1*topic_0 + topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 
                 + topic_1*topic_4 + topic_1*topic_5 + topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 
                 + topic_1*topic_9 + topic_1*topic_10 + topic_1*topic_11 + topic_1*topic_12 + topic_1*topic_13 
                 + topic_1*topic_14 + topic_1*topic_15 + topic_1*topic_16 + topic_1*topic_17 + topic_1*topic_18 
                 + topic_1*topic_19 + topic_1*topic_20 + topic_1*topic_21 + topic_1*topic_22 + topic_1*topic_23 
                 + topic_2*topic_0 + topic_2*topic_1 + topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 
                 + topic_2*topic_5 + topic_2*topic_6 + topic_2*topic_7 + topic_2*topic_8 + topic_2*topic_9 
                 + topic_2*topic_10 + topic_2*topic_11 + topic_2*topic_12 + topic_2*topic_13 + topic_2*topic_14 
                 + topic_2*topic_15 + topic_2*topic_16 + topic_2*topic_17 + topic_2*topic_18 + topic_2*topic_19 
                 + topic_2*topic_20 + topic_2*topic_21 + topic_2*topic_22 + topic_2*topic_23 + topic_3*topic_0 
                 + topic_3*topic_1 + topic_3*topic_2 + topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 
                 + topic_3*topic_6 + topic_3*topic_7 + topic_3*topic_8 + topic_3*topic_9 + topic_3*topic_10 
                 + topic_3*topic_11 + topic_3*topic_12 + topic_3*topic_13 + topic_3*topic_14 + topic_3*topic_15 
                 + topic_3*topic_16 + topic_3*topic_17 + topic_3*topic_18 + topic_3*topic_19 + topic_3*topic_20 
                 + topic_3*topic_21 + topic_3*topic_22 + topic_3*topic_23 + topic_4*topic_0 + topic_4*topic_1 
                 + topic_4*topic_2 + topic_4*topic_3 + topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 
                 + topic_4*topic_7 + topic_4*topic_8 + topic_4*topic_9 + topic_4*topic_10 + topic_4*topic_11 
                 + topic_4*topic_12 + topic_4*topic_13 + topic_4*topic_14 + topic_4*topic_15 + topic_4*topic_16 
                 + topic_4*topic_17 + topic_4*topic_18 + topic_4*topic_19 + topic_4*topic_20 + topic_4*topic_21 
                 + topic_4*topic_22 + topic_4*topic_23 + topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 
                 + topic_5*topic_3 + topic_5*topic_4 + topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 
                 + topic_5*topic_8 + topic_5*topic_9 + topic_5*topic_10 + topic_5*topic_11 + topic_5*topic_12 
                 + topic_5*topic_13 + topic_5*topic_14 + topic_5*topic_15 + topic_5*topic_16 + topic_5*topic_17 
                 + topic_5*topic_18 + topic_5*topic_19 + topic_5*topic_20 + topic_5*topic_21 + topic_5*topic_22 
                 + topic_5*topic_23 + topic_6*topic_0 + topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 
                 + topic_6*topic_4 + topic_6*topic_5 + topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 
                 + topic_6*topic_9 + topic_6*topic_10 + topic_6*topic_11 + topic_6*topic_12 + topic_6*topic_13 
                 + topic_6*topic_14 + topic_6*topic_15 + topic_6*topic_16 + topic_6*topic_17 + topic_6*topic_18
                 + topic_6*topic_19 + topic_6*topic_20 + topic_6*topic_21 + topic_6*topic_22 + topic_6*topic_23
                 + topic_7*topic_0 + topic_7*topic_1 + topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 
                 + topic_7*topic_5 + topic_7*topic_6 + topic_7*topic_7 + topic_7*topic_8 + topic_7*topic_9 
                 + topic_7*topic_10 + topic_7*topic_11 + topic_7*topic_12 + topic_7*topic_13 + topic_7*topic_14 
                 + topic_7*topic_15 + topic_7*topic_16 + topic_7*topic_17 + topic_7*topic_18 + topic_7*topic_19 
                 + topic_7*topic_20 + topic_7*topic_21 + topic_7*topic_22 + topic_7*topic_23 + topic_8*topic_0 
                 + topic_8*topic_1 + topic_8*topic_2 + topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 
                 + topic_8*topic_7 + topic_8*topic_8 + topic_8*topic_9 + topic_8*topic_10 + topic_8*topic_11 + topic_8*topic_12
                 + topic_8*topic_13 + topic_8*topic_14 + topic_8*topic_15 + topic_8*topic_16 + topic_8*topic_17
                 + topic_8*topic_18 + topic_8*topic_19 + topic_8*topic_20 + topic_8*topic_21 + topic_8*topic_22
                 + topic_8*topic_23 + topic_9*topic_0 + topic_9*topic_1 + topic_9*topic_2 + topic_9*topic_3 
                 + topic_9*topic_4 + topic_9*topic_5 + topic_9*topic_6 + topic_9*topic_7 + topic_9*topic_8 
                 + topic_9*topic_9 + topic_9*topic_10 + topic_9*topic_11 + topic_9*topic_12 + topic_9*topic_13 
                 + topic_9*topic_14 + topic_9*topic_15 + topic_9*topic_16 + topic_9*topic_17 + topic_9*topic_18
                 + topic_9*topic_19 + topic_9*topic_20 + topic_9*topic_21 + topic_9*topic_22 + topic_9*topic_23
                 + topic_10*topic_0 + topic_10*topic_1 + topic_10*topic_2 + topic_10*topic_3 + topic_10*topic_4 
                 + topic_10*topic_5 + topic_10*topic_6 + topic_10*topic_7 + topic_10*topic_8 + topic_10*topic_9 
                 + topic_10*topic_10 + topic_10*topic_11 + topic_10*topic_12 + topic_10*topic_13 + topic_10*topic_14
                 + topic_10*topic_15 + topic_10*topic_16 + topic_10*topic_17 + topic_10*topic_18 + topic_10*topic_19 
                 + topic_10*topic_20 + topic_10*topic_21 + topic_10*topic_22 + topic_10*topic_23 + topic_11*topic_0 
                 + topic_11*topic_1 + topic_11*topic_2 + topic_11*topic_3 + topic_11*topic_4 + topic_11*topic_5 
                 + topic_11*topic_6 + topic_11*topic_7 + topic_11*topic_8 + topic_11*topic_9 + topic_11*topic_10 
                 + topic_11*topic_11 + topic_11*topic_12 + topic_11*topic_13 + topic_11*topic_14 + topic_11*topic_15 
                 + topic_11*topic_16 + topic_11*topic_17 + topic_11*topic_18 + topic_11*topic_19 + topic_11*topic_20 + topic_11*topic_21 + topic_11*topic_22 + topic_11*topic_23 + topic_12*topic_0 + topic_12*topic_1 + topic_12*topic_2 + topic_12*topic_3 + topic_12*topic_4 + topic_12*topic_5 + topic_12*topic_6 + topic_12*topic_7 + topic_12*topic_8 + topic_12*topic_9 + topic_12*topic_10 + topic_12*topic_11 + topic_12*topic_12 + topic_12*topic_13 + topic_12*topic_14 + topic_12*topic_15 + topic_12*topic_16 + topic_12*topic_17 + topic_12*topic_18 + topic_12*topic_19 + topic_12*topic_20 + topic_12*topic_21 + topic_12*topic_22 + topic_12*topic_23 + topic_13*topic_0 + topic_13*topic_1 + topic_13*topic_2 + topic_13*topic_3 + topic_13*topic_4 + topic_13*topic_5 + topic_13*topic_6 + topic_13*topic_7 + topic_13*topic_8 + topic_13*topic_9 + topic_13*topic_10 + topic_13*topic_11 + topic_13*topic_12 + topic_13*topic_13 + topic_13*topic_14 + topic_13*topic_15 + topic_13*topic_16 + topic_13*topic_17 + topic_13*topic_18 + topic_13*topic_19 + topic_13*topic_20 + topic_13*topic_21 + topic_13*topic_22 + topic_13*topic_23 + topic_14*topic_0 + topic_14*topic_1 + topic_14*topic_2 + topic_14*topic_3 + topic_14*topic_4 + topic_14*topic_5 + topic_14*topic_6 + topic_14*topic_7 + topic_14*topic_8 + topic_14*topic_9 + topic_14*topic_10 + topic_14*topic_11 + topic_14*topic_12 + topic_14*topic_13 + topic_14*topic_14 + topic_14*topic_15 + topic_14*topic_16 + topic_14*topic_17 + topic_14*topic_18 + topic_14*topic_19 + topic_14*topic_20 + topic_14*topic_21 + topic_14*topic_22 + topic_14*topic_23 + topic_15*topic_0 + topic_15*topic_1 + topic_15*topic_2 + topic_15*topic_3 + topic_15*topic_4 + topic_15*topic_5 + topic_15*topic_6 + topic_15*topic_7 + topic_15*topic_8 + topic_15*topic_9 + topic_15*topic_10 + topic_15*topic_11 + topic_15*topic_12 + topic_15*topic_13 + topic_15*topic_14 + topic_15*topic_15 + topic_15*topic_16 + topic_15*topic_17 + topic_15*topic_18 + topic_15*topic_19 + topic_15*topic_20 + topic_15*topic_21 + topic_15*topic_22 + topic_15*topic_23 + topic_16*topic_0 + topic_16*topic_1 + topic_16*topic_2 + topic_16*topic_3 + topic_16*topic_4 + topic_16*topic_5 + topic_16*topic_6 + topic_16*topic_7 + topic_16*topic_8 + topic_16*topic_9 + topic_16*topic_10 + topic_16*topic_11 + topic_16*topic_12 + topic_16*topic_13 + topic_16*topic_14 + topic_16*topic_15 + topic_16*topic_16 + topic_16*topic_17 + topic_16*topic_18 + topic_16*topic_19 + topic_16*topic_20 + topic_16*topic_21 + topic_16*topic_22 + topic_16*topic_23 + topic_17*topic_0 + topic_17*topic_1 + topic_17*topic_2 + topic_17*topic_3 + topic_17*topic_4 + topic_17*topic_5 + topic_17*topic_6 + topic_17*topic_7 + topic_17*topic_8 + topic_17*topic_9 + topic_17*topic_10 + topic_17*topic_11 + topic_17*topic_12 + topic_17*topic_13 + topic_17*topic_14 + topic_17*topic_15 + topic_17*topic_16 + topic_17*topic_17 + topic_17*topic_18 + topic_17*topic_19 + topic_17*topic_20 + topic_17*topic_21 + topic_17*topic_22 + topic_17*topic_23 + topic_18*topic_0 + topic_18*topic_1 + topic_18*topic_2 + topic_18*topic_3 + topic_18*topic_4 + topic_18*topic_5 + topic_18*topic_6 + topic_18*topic_7 + topic_18*topic_8 + topic_18*topic_9 + topic_18*topic_10 + topic_18*topic_11 + topic_18*topic_12 + topic_18*topic_13 + topic_18*topic_14 + topic_18*topic_15 + topic_18*topic_16 + topic_18*topic_17 + topic_18*topic_18 + topic_18*topic_19 + topic_18*topic_20 + topic_18*topic_21 + topic_18*topic_22 + topic_18*topic_23 + topic_19*topic_0 + topic_19*topic_1 + topic_19*topic_2 + topic_19*topic_3 + topic_19*topic_4 + topic_19*topic_5 + topic_19*topic_6 + topic_19*topic_7 + topic_19*topic_8 + topic_19*topic_9 + topic_19*topic_10 + topic_19*topic_11 + topic_19*topic_12 + topic_19*topic_13 + topic_19*topic_14 + topic_19*topic_15 + topic_19*topic_16 + topic_19*topic_17 + topic_19*topic_18 + topic_19*topic_19 + topic_19*topic_20 + topic_19*topic_21 + topic_19*topic_22 + topic_19*topic_23 + topic_20*topic_0 + topic_20*topic_1 + topic_20*topic_2 + topic_20*topic_3 + topic_20*topic_4 + topic_20*topic_5 + topic_20*topic_6 + topic_20*topic_7 + topic_20*topic_8 + topic_20*topic_9 + topic_20*topic_10 + topic_20*topic_11 + topic_20*topic_12 + topic_20*topic_13 + topic_20*topic_14 + topic_20*topic_15 + topic_20*topic_16 + topic_20*topic_17 + topic_20*topic_18 + topic_20*topic_19 + topic_20*topic_20 + topic_20*topic_21 + topic_20*topic_22 + topic_20*topic_23 + topic_21*topic_0 + topic_21*topic_1 + topic_21*topic_2 + topic_21*topic_3 + topic_21*topic_4 + topic_21*topic_5 + topic_21*topic_6 + topic_21*topic_7 + topic_21*topic_8 + topic_21*topic_9 + topic_21*topic_10 + topic_21*topic_11 + topic_21*topic_12 + topic_21*topic_13 + topic_21*topic_14 + topic_21*topic_15 + topic_21*topic_16 + topic_21*topic_17 + topic_21*topic_18 + topic_21*topic_19 + topic_21*topic_20 + topic_21*topic_21 + topic_21*topic_22 + topic_21*topic_23 + topic_22*topic_0 + topic_22*topic_1 + topic_22*topic_2 + topic_22*topic_3 + topic_22*topic_4 + topic_22*topic_5 + topic_22*topic_6 + topic_22*topic_7 + topic_22*topic_8 + topic_22*topic_9 + topic_22*topic_10 + topic_22*topic_11 + topic_22*topic_12 + topic_22*topic_13 + topic_22*topic_14 + topic_22*topic_15 + topic_22*topic_16 + topic_22*topic_17 + topic_22*topic_18 + topic_22*topic_19 + topic_22*topic_20 + topic_22*topic_21 + topic_22*topic_22 + topic_22*topic_23 + topic_23*topic_0 + topic_23*topic_1 + topic_23*topic_2 + topic_23*topic_3 + topic_23*topic_4 + topic_23*topic_5 + topic_23*topic_6 + topic_23*topic_7 + topic_23*topic_8 + topic_23*topic_9 + topic_23*topic_10 + topic_23*topic_11 
                 + topic_23*topic_12 + topic_23*topic_13 + topic_23*topic_14 + topic_23*topic_15 + topic_23*topic_16 
                 + topic_23*topic_17 + topic_23*topic_18 + topic_23*topic_19 + topic_23*topic_20 + topic_23*topic_21 
                 + topic_23*topic_22 + topic_23*topic_23
, data = data)
# Stepwise regression model
step_model_first_comment <- stepAIC(full_model_first_comment, direction = "both", 
                      trace = FALSE)
summary(step_model_first_comment)
# Out:
# Call:
# lm(formula = avg_first_comment ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     total_contributors + project_age + topic_0 + topic_1 + topic_2 +
#     topic_3 + topic_4 + topic_5 + topic_6 + topic_7 + topic_8 +
#     topic_9 + topic_10 + topic_11 + topic_12 + topic_13 + topic_14 +
#     topic_15 + topic_16 + topic_17 + topic_18 + topic_19 + topic_20 +
#     topic_21 + topic_22 + topic_23 + topic_0:topic_5 + topic_0:topic_11 +
#     topic_0:topic_12 + topic_0:topic_13 + topic_0:topic_15 +
#     topic_0:topic_21 + topic_1:topic_3 + topic_1:topic_4 + topic_1:topic_7 +
#     topic_1:topic_8 + topic_1:topic_11 + topic_1:topic_12 + topic_1:topic_17 +
#     topic_1:topic_19 + topic_1:topic_21 + topic_1:topic_22 +
#     topic_2:topic_6 + topic_2:topic_7 + topic_2:topic_12 + topic_2:topic_13 +
#     topic_2:topic_14 + topic_2:topic_15 + topic_2:topic_18 +
# ...

# %% [markdown]
# ### Issues Per User

# %%
full_model_issues_per_user <- lm(issues_per_user ~ crowd_pct + crowd_pct_2 + avg_clustering + avg_min_path + gini_coefficient 
                 + avg_clusteringXcrowd_pct + avg_min_pathXcrowd_pct + gini_coefficientXcrowd_pct 
                 + total_contributors + project_age + topic_0*topic_0 + topic_0*topic_1 + topic_0*topic_2 
                 + topic_0*topic_3 + topic_0*topic_4 + topic_0*topic_5 + topic_0*topic_6 + topic_0*topic_7 
                 + topic_0*topic_8 + topic_0*topic_9 + topic_0*topic_10 + topic_0*topic_11 + topic_0*topic_12
                 + topic_0*topic_13 + topic_0*topic_14 + topic_0*topic_15 + topic_0*topic_16 + topic_0*topic_17 
                 + topic_0*topic_18 + topic_0*topic_19 + topic_0*topic_20 + topic_0*topic_21 + topic_0*topic_22
                 + topic_0*topic_23 + topic_1*topic_0 + topic_1*topic_1 + topic_1*topic_2 + topic_1*topic_3 
                 + topic_1*topic_4 + topic_1*topic_5 + topic_1*topic_6 + topic_1*topic_7 + topic_1*topic_8 
                 + topic_1*topic_9 + topic_1*topic_10 + topic_1*topic_11 + topic_1*topic_12 + topic_1*topic_13 
                 + topic_1*topic_14 + topic_1*topic_15 + topic_1*topic_16 + topic_1*topic_17 + topic_1*topic_18 
                 + topic_1*topic_19 + topic_1*topic_20 + topic_1*topic_21 + topic_1*topic_22 + topic_1*topic_23 
                 + topic_2*topic_0 + topic_2*topic_1 + topic_2*topic_2 + topic_2*topic_3 + topic_2*topic_4 
                 + topic_2*topic_5 + topic_2*topic_6 + topic_2*topic_7 + topic_2*topic_8 + topic_2*topic_9 
                 + topic_2*topic_10 + topic_2*topic_11 + topic_2*topic_12 + topic_2*topic_13 + topic_2*topic_14 
                 + topic_2*topic_15 + topic_2*topic_16 + topic_2*topic_17 + topic_2*topic_18 + topic_2*topic_19 
                 + topic_2*topic_20 + topic_2*topic_21 + topic_2*topic_22 + topic_2*topic_23 + topic_3*topic_0 
                 + topic_3*topic_1 + topic_3*topic_2 + topic_3*topic_3 + topic_3*topic_4 + topic_3*topic_5 
                 + topic_3*topic_6 + topic_3*topic_7 + topic_3*topic_8 + topic_3*topic_9 + topic_3*topic_10 
                 + topic_3*topic_11 + topic_3*topic_12 + topic_3*topic_13 + topic_3*topic_14 + topic_3*topic_15 
                 + topic_3*topic_16 + topic_3*topic_17 + topic_3*topic_18 + topic_3*topic_19 + topic_3*topic_20 
                 + topic_3*topic_21 + topic_3*topic_22 + topic_3*topic_23 + topic_4*topic_0 + topic_4*topic_1 
                 + topic_4*topic_2 + topic_4*topic_3 + topic_4*topic_4 + topic_4*topic_5 + topic_4*topic_6 
                 + topic_4*topic_7 + topic_4*topic_8 + topic_4*topic_9 + topic_4*topic_10 + topic_4*topic_11 
                 + topic_4*topic_12 + topic_4*topic_13 + topic_4*topic_14 + topic_4*topic_15 + topic_4*topic_16 
                 + topic_4*topic_17 + topic_4*topic_18 + topic_4*topic_19 + topic_4*topic_20 + topic_4*topic_21 
                 + topic_4*topic_22 + topic_4*topic_23 + topic_5*topic_0 + topic_5*topic_1 + topic_5*topic_2 
                 + topic_5*topic_3 + topic_5*topic_4 + topic_5*topic_5 + topic_5*topic_6 + topic_5*topic_7 
                 + topic_5*topic_8 + topic_5*topic_9 + topic_5*topic_10 + topic_5*topic_11 + topic_5*topic_12 
                 + topic_5*topic_13 + topic_5*topic_14 + topic_5*topic_15 + topic_5*topic_16 + topic_5*topic_17 
                 + topic_5*topic_18 + topic_5*topic_19 + topic_5*topic_20 + topic_5*topic_21 + topic_5*topic_22 
                 + topic_5*topic_23 + topic_6*topic_0 + topic_6*topic_1 + topic_6*topic_2 + topic_6*topic_3 
                 + topic_6*topic_4 + topic_6*topic_5 + topic_6*topic_6 + topic_6*topic_7 + topic_6*topic_8 
                 + topic_6*topic_9 + topic_6*topic_10 + topic_6*topic_11 + topic_6*topic_12 + topic_6*topic_13 
                 + topic_6*topic_14 + topic_6*topic_15 + topic_6*topic_16 + topic_6*topic_17 + topic_6*topic_18
                 + topic_6*topic_19 + topic_6*topic_20 + topic_6*topic_21 + topic_6*topic_22 + topic_6*topic_23
                 + topic_7*topic_0 + topic_7*topic_1 + topic_7*topic_2 + topic_7*topic_3 + topic_7*topic_4 
                 + topic_7*topic_5 + topic_7*topic_6 + topic_7*topic_7 + topic_7*topic_8 + topic_7*topic_9 
                 + topic_7*topic_10 + topic_7*topic_11 + topic_7*topic_12 + topic_7*topic_13 + topic_7*topic_14 
                 + topic_7*topic_15 + topic_7*topic_16 + topic_7*topic_17 + topic_7*topic_18 + topic_7*topic_19 
                 + topic_7*topic_20 + topic_7*topic_21 + topic_7*topic_22 + topic_7*topic_23 + topic_8*topic_0 
                 + topic_8*topic_1 + topic_8*topic_2 + topic_8*topic_3 + topic_8*topic_4 + topic_8*topic_5 + topic_8*topic_6 
                 + topic_8*topic_7 + topic_8*topic_8 + topic_8*topic_9 + topic_8*topic_10 + topic_8*topic_11 + topic_8*topic_12
                 + topic_8*topic_13 + topic_8*topic_14 + topic_8*topic_15 + topic_8*topic_16 + topic_8*topic_17
                 + topic_8*topic_18 + topic_8*topic_19 + topic_8*topic_20 + topic_8*topic_21 + topic_8*topic_22
                 + topic_8*topic_23 + topic_9*topic_0 + topic_9*topic_1 + topic_9*topic_2 + topic_9*topic_3 
                 + topic_9*topic_4 + topic_9*topic_5 + topic_9*topic_6 + topic_9*topic_7 + topic_9*topic_8 
                 + topic_9*topic_9 + topic_9*topic_10 + topic_9*topic_11 + topic_9*topic_12 + topic_9*topic_13 
                 + topic_9*topic_14 + topic_9*topic_15 + topic_9*topic_16 + topic_9*topic_17 + topic_9*topic_18
                 + topic_9*topic_19 + topic_9*topic_20 + topic_9*topic_21 + topic_9*topic_22 + topic_9*topic_23
                 + topic_10*topic_0 + topic_10*topic_1 + topic_10*topic_2 + topic_10*topic_3 + topic_10*topic_4 
                 + topic_10*topic_5 + topic_10*topic_6 + topic_10*topic_7 + topic_10*topic_8 + topic_10*topic_9 
                 + topic_10*topic_10 + topic_10*topic_11 + topic_10*topic_12 + topic_10*topic_13 + topic_10*topic_14
                 + topic_10*topic_15 + topic_10*topic_16 + topic_10*topic_17 + topic_10*topic_18 + topic_10*topic_19 
                 + topic_10*topic_20 + topic_10*topic_21 + topic_10*topic_22 + topic_10*topic_23 + topic_11*topic_0 
                 + topic_11*topic_1 + topic_11*topic_2 + topic_11*topic_3 + topic_11*topic_4 + topic_11*topic_5 
                 + topic_11*topic_6 + topic_11*topic_7 + topic_11*topic_8 + topic_11*topic_9 + topic_11*topic_10 
                 + topic_11*topic_11 + topic_11*topic_12 + topic_11*topic_13 + topic_11*topic_14 + topic_11*topic_15 
                 + topic_11*topic_16 + topic_11*topic_17 + topic_11*topic_18 + topic_11*topic_19 + topic_11*topic_20 + topic_11*topic_21 + topic_11*topic_22 + topic_11*topic_23 + topic_12*topic_0 + topic_12*topic_1 + topic_12*topic_2 + topic_12*topic_3 + topic_12*topic_4 + topic_12*topic_5 + topic_12*topic_6 + topic_12*topic_7 + topic_12*topic_8 + topic_12*topic_9 + topic_12*topic_10 + topic_12*topic_11 + topic_12*topic_12 + topic_12*topic_13 + topic_12*topic_14 + topic_12*topic_15 + topic_12*topic_16 + topic_12*topic_17 + topic_12*topic_18 + topic_12*topic_19 + topic_12*topic_20 + topic_12*topic_21 + topic_12*topic_22 + topic_12*topic_23 + topic_13*topic_0 + topic_13*topic_1 + topic_13*topic_2 + topic_13*topic_3 + topic_13*topic_4 + topic_13*topic_5 + topic_13*topic_6 + topic_13*topic_7 + topic_13*topic_8 + topic_13*topic_9 + topic_13*topic_10 + topic_13*topic_11 + topic_13*topic_12 + topic_13*topic_13 + topic_13*topic_14 + topic_13*topic_15 + topic_13*topic_16 + topic_13*topic_17 + topic_13*topic_18 + topic_13*topic_19 + topic_13*topic_20 + topic_13*topic_21 + topic_13*topic_22 + topic_13*topic_23 + topic_14*topic_0 + topic_14*topic_1 + topic_14*topic_2 + topic_14*topic_3 + topic_14*topic_4 + topic_14*topic_5 + topic_14*topic_6 + topic_14*topic_7 + topic_14*topic_8 + topic_14*topic_9 + topic_14*topic_10 + topic_14*topic_11 + topic_14*topic_12 + topic_14*topic_13 + topic_14*topic_14 + topic_14*topic_15 + topic_14*topic_16 + topic_14*topic_17 + topic_14*topic_18 + topic_14*topic_19 + topic_14*topic_20 + topic_14*topic_21 + topic_14*topic_22 + topic_14*topic_23 + topic_15*topic_0 + topic_15*topic_1 + topic_15*topic_2 + topic_15*topic_3 + topic_15*topic_4 + topic_15*topic_5 + topic_15*topic_6 + topic_15*topic_7 + topic_15*topic_8 + topic_15*topic_9 + topic_15*topic_10 + topic_15*topic_11 + topic_15*topic_12 + topic_15*topic_13 + topic_15*topic_14 + topic_15*topic_15 + topic_15*topic_16 + topic_15*topic_17 + topic_15*topic_18 + topic_15*topic_19 + topic_15*topic_20 + topic_15*topic_21 + topic_15*topic_22 + topic_15*topic_23 + topic_16*topic_0 + topic_16*topic_1 + topic_16*topic_2 + topic_16*topic_3 + topic_16*topic_4 + topic_16*topic_5 + topic_16*topic_6 + topic_16*topic_7 + topic_16*topic_8 + topic_16*topic_9 + topic_16*topic_10 + topic_16*topic_11 + topic_16*topic_12 + topic_16*topic_13 + topic_16*topic_14 + topic_16*topic_15 + topic_16*topic_16 + topic_16*topic_17 + topic_16*topic_18 + topic_16*topic_19 + topic_16*topic_20 + topic_16*topic_21 + topic_16*topic_22 + topic_16*topic_23 + topic_17*topic_0 + topic_17*topic_1 + topic_17*topic_2 + topic_17*topic_3 + topic_17*topic_4 + topic_17*topic_5 + topic_17*topic_6 + topic_17*topic_7 + topic_17*topic_8 + topic_17*topic_9 + topic_17*topic_10 + topic_17*topic_11 + topic_17*topic_12 + topic_17*topic_13 + topic_17*topic_14 + topic_17*topic_15 + topic_17*topic_16 + topic_17*topic_17 + topic_17*topic_18 + topic_17*topic_19 + topic_17*topic_20 + topic_17*topic_21 + topic_17*topic_22 + topic_17*topic_23 + topic_18*topic_0 + topic_18*topic_1 + topic_18*topic_2 + topic_18*topic_3 + topic_18*topic_4 + topic_18*topic_5 + topic_18*topic_6 + topic_18*topic_7 + topic_18*topic_8 + topic_18*topic_9 + topic_18*topic_10 + topic_18*topic_11 + topic_18*topic_12 + topic_18*topic_13 + topic_18*topic_14 + topic_18*topic_15 + topic_18*topic_16 + topic_18*topic_17 + topic_18*topic_18 + topic_18*topic_19 + topic_18*topic_20 + topic_18*topic_21 + topic_18*topic_22 + topic_18*topic_23 + topic_19*topic_0 + topic_19*topic_1 + topic_19*topic_2 + topic_19*topic_3 + topic_19*topic_4 + topic_19*topic_5 + topic_19*topic_6 + topic_19*topic_7 + topic_19*topic_8 + topic_19*topic_9 + topic_19*topic_10 + topic_19*topic_11 + topic_19*topic_12 + topic_19*topic_13 + topic_19*topic_14 + topic_19*topic_15 + topic_19*topic_16 + topic_19*topic_17 + topic_19*topic_18 + topic_19*topic_19 + topic_19*topic_20 + topic_19*topic_21 + topic_19*topic_22 + topic_19*topic_23 + topic_20*topic_0 + topic_20*topic_1 + topic_20*topic_2 + topic_20*topic_3 + topic_20*topic_4 + topic_20*topic_5 + topic_20*topic_6 + topic_20*topic_7 + topic_20*topic_8 + topic_20*topic_9 + topic_20*topic_10 + topic_20*topic_11 + topic_20*topic_12 + topic_20*topic_13 + topic_20*topic_14 + topic_20*topic_15 + topic_20*topic_16 + topic_20*topic_17 + topic_20*topic_18 + topic_20*topic_19 + topic_20*topic_20 + topic_20*topic_21 + topic_20*topic_22 + topic_20*topic_23 + topic_21*topic_0 + topic_21*topic_1 + topic_21*topic_2 + topic_21*topic_3 + topic_21*topic_4 + topic_21*topic_5 + topic_21*topic_6 + topic_21*topic_7 + topic_21*topic_8 + topic_21*topic_9 + topic_21*topic_10 + topic_21*topic_11 + topic_21*topic_12 + topic_21*topic_13 + topic_21*topic_14 + topic_21*topic_15 + topic_21*topic_16 + topic_21*topic_17 + topic_21*topic_18 + topic_21*topic_19 + topic_21*topic_20 + topic_21*topic_21 + topic_21*topic_22 + topic_21*topic_23 + topic_22*topic_0 + topic_22*topic_1 + topic_22*topic_2 + topic_22*topic_3 + topic_22*topic_4 + topic_22*topic_5 + topic_22*topic_6 + topic_22*topic_7 + topic_22*topic_8 + topic_22*topic_9 + topic_22*topic_10 + topic_22*topic_11 + topic_22*topic_12 + topic_22*topic_13 + topic_22*topic_14 + topic_22*topic_15 + topic_22*topic_16 + topic_22*topic_17 + topic_22*topic_18 + topic_22*topic_19 + topic_22*topic_20 + topic_22*topic_21 + topic_22*topic_22 + topic_22*topic_23 + topic_23*topic_0 + topic_23*topic_1 + topic_23*topic_2 + topic_23*topic_3 + topic_23*topic_4 + topic_23*topic_5 + topic_23*topic_6 + topic_23*topic_7 + topic_23*topic_8 + topic_23*topic_9 + topic_23*topic_10 + topic_23*topic_11 
                 + topic_23*topic_12 + topic_23*topic_13 + topic_23*topic_14 + topic_23*topic_15 + topic_23*topic_16 
                 + topic_23*topic_17 + topic_23*topic_18 + topic_23*topic_19 + topic_23*topic_20 + topic_23*topic_21 
                 + topic_23*topic_22 + topic_23*topic_23
, data = data)
# Stepwise regression model
step_model_issues_per_user <- stepAIC(full_model_issues_per_user, direction = "both", 
                      trace = FALSE)
summary(step_model_issues_per_user)
# Out:
# Call:
# lm(formula = issues_per_user ~ crowd_pct + crowd_pct_2 + avg_clustering +
#     avg_min_path + gini_coefficient + avg_clusteringXcrowd_pct +
#     gini_coefficientXcrowd_pct + topic_0 + topic_1 + topic_2 +
#     topic_3 + topic_4 + topic_5 + topic_6 + topic_7 + topic_8 +
#     topic_9 + topic_10 + topic_11 + topic_12 + topic_13 + topic_14 +
#     topic_15 + topic_16 + topic_17 + topic_18 + topic_19 + topic_20 +
#     topic_21 + topic_22 + topic_23 + topic_0:topic_2 + topic_0:topic_7 +
#     topic_0:topic_15 + topic_1:topic_4 + topic_1:topic_7 + topic_1:topic_13 +
#     topic_1:topic_14 + topic_1:topic_17 + topic_2:topic_3 + topic_2:topic_8 +
#     topic_2:topic_9 + topic_2:topic_12 + topic_3:topic_4 + topic_3:topic_7 +
#     topic_3:topic_14 + topic_3:topic_18 + topic_4:topic_5 + topic_4:topic_9 +
#     topic_4:topic_11 + topic_4:topic_13 + topic_4:topic_15 +
#     topic_4:topic_17 + topic_4:topic_18 + topic_4:topic_19 +
# ...
